# %% [markdown]
# # GUI class

# %%
import matplotlib
matplotlib.use('Agg')
import tkinter as tk
from tkinter import ttk
import pandas as pd
import tkinter.font as tkFont
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
matplotlib.use('Agg')
import pickle
from PIL import Image, ImageTk

with open('city_area_road.pkl', 'rb') as f:
    data1 = {"縣市": ''}
    data2 = pickle.load(f)
    data2['南海島'] = {'南海島':'南海島'}
    data = {}
    data.update(data1)
    data.update(data2)

selected_list = [[], [], []]


class Design(tk.Frame):
    def __int__(self):
        tk.Frame.__int__(self)
        self.grid()

    def Drop_down_list(self, title, title_row):
        self.title_row = title_row
        labelTop = tk.Label(cal, text = title)
        labelTop.grid(column = 0, row = title_row)
        self.City = ttk.Combobox(cal, values = list(data.keys()))
        self.City.grid(column = 1, row = title_row)
        self.City.current(0)
        self.Region = ttk.Combobox(cal, values = ["鄉鎮區"])
        self.Region.grid(column = 2, row = title_row)
        self.Region.current(0)
        self.City.bind("<<ComboboxSelected>>", self.Chosen)

    def Chosen(self, city):
        self.var_Selected = self.City.get()
        self.Region = ttk.Combobox(cal, values = list(data[self.var_Selected].keys()))
        self.Region.grid(column = 2, row = self.title_row)
        self.Region.current(0)
        self.Region.bind("<<ComboboxSelected>>", self.Saved)

    def Saved(self, event):
        selected_city = self.City.get()
        selected_region = self.Region.get()
        if selected_list[self.title_row] == []:
            selected_list[self.title_row] = [selected_city, selected_region]
        else:
            selected_list[self.title_row][0] = selected_city
            selected_list[self.title_row][1] = selected_region
         
    def update_scrollregion(self, event):
        self.Canvas.configure(scrollregion=self.Canvas.bbox("all"))

    def Search(self):
        print(selected_list)
        plt.clf()
        pic = draw(selected_list)
        f1 = tkFont.Font(family='microsoft yahei', size=25, weight='bold')
        f2 = tkFont.Font(family='microsoft yahei', size=15, weight='bold')
        f3 = tkFont.Font(family='microsoft yahei', size=40, weight='bold')
        
        
        if (selected_list[0][0] == '釣魚臺') or (selected_list[1][0] == '釣魚臺') or (selected_list[2][0] == '釣魚臺'):
            # 建立Frame、Canvas及Canvasframe
            self.Frame = tk.Frame(cal, width=1425, height=700, bg="white")
            self.Frame.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
            self.Frame.rowconfigure(0, weight=1) 
            self.Frame.columnconfigure(0, weight=1)
        
            self.Canvas = tk.Canvas(self.Frame, width=1425, height=500, bg="white")
            self.Canvas.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
        
            self.CanvasFrame = tk.Frame(self.Canvas, width=1425, height=700, bg="white")
            #self.Canvas.create_window(0, 0, window=self.CanvasFrame, anchor='nw')
            
            self.easter_egg1 =img = ImageTk.PhotoImage(Image.open('easter_egg1-1.gif').resize((1412, 476),Image.ANTIALIAS)) 
            self.image = self.Canvas.create_image(10,10,anchor = 'nw',image = self.easter_egg1)
            self.Canvas.pack()
            


        elif(selected_list[0][0] == '南海島') or (selected_list[1][0] == '南海島') or (selected_list[2][0] == '南海島'):
            self.Frame = tk.Frame(cal, width=1425, height=700, bg="blue")
            self.Frame.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
            self.Frame.rowconfigure(0, weight=1) 
            self.Frame.columnconfigure(0, weight=1)
        
            self.Canvas = tk.Canvas(self.Frame, width=1425, height=700, bg="lightcyan")
            self.Canvas.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
        
            self.CanvasFrame = tk.Frame(self.Canvas, width=1425, height=700, bg="white")
            self.Canvas.create_window(0, 0, window=self.CanvasFrame, anchor='nw')
            self.bus_label = tk.Label(self.CanvasFrame, text='海南島在哪裡？', font = f1, bg = "lightcyan")
            self.bus_label.grid(column = 1, row = 3, columnspan = 3, sticky="nsew")
            
            
            self.easter_egg2 =img = ImageTk.PhotoImage(Image.open('easter_egg2-1.gif').resize((500, 500),Image.ANTIALIAS)) 
            self.image = self.Canvas.create_image(10,40,anchor = 'nw',image = self.easter_egg2)
            self.easter_egg3 =img = ImageTk.PhotoImage(Image.open('easter_egg2-2.gif').resize((500, 500),Image.ANTIALIAS)) 
            self.image = self.Canvas.create_image(510,40,anchor = 'nw',image = self.easter_egg3)
            
            self.Canvas.pack()
            
            
            
            
            
        else:
            # 建立Frame、Canvas及Canvasframe
            self.Frame = tk.Frame(cal, width=1425, height=700, bg="white")
            self.Frame.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
            self.Frame.rowconfigure(0, weight=1) 
            self.Frame.columnconfigure(0, weight=1)
        
            self.Canvas = tk.Canvas(self.Frame, width=1425, height=700, bg="white")
            self.Canvas.grid(row=3, column=0, columnspan = 2000, sticky="nsew")
        
            self.CanvasFrame = tk.Frame(self.Canvas, width=1425, height=700, bg="white")
            self.Canvas.create_window(0, 0, window=self.CanvasFrame, anchor='nw')

            # 最上方數字呈現
            self.bus_label = tk.Label(self.CanvasFrame, text='公車站牌密度(個/平方公里)', font = f1, bg = "white")
            self.bus_label.grid(column = 1, row = 3, columnspan = 3, sticky="nsew")
        
            self.bus_label_Region1 = tk.Label(self.CanvasFrame, text=selected_list[0][1], font = f2, bg = "white")
            self.bus_label_Region1.grid(column = 1, row = 4, sticky="nsew")
            self.bus_label_Region2 = tk.Label(self.CanvasFrame, text=selected_list[1][1], font = f2, bg = "white")
            self.bus_label_Region2.grid(column = 2, row = 4, sticky="nsew")
            self.bus_label_Region3 = tk.Label(self.CanvasFrame, text=selected_list[2][1], font = f2, bg = "white")
            self.bus_label_Region3.grid(column = 3, row = 4, sticky="nsew")
        
            self.bus_number_Region1 = tk.Label(self.CanvasFrame, text=str(round(pic.transport_density()[0][0],1)), font = f3, bg = "white")
            self.bus_number_Region1.grid(column = 1, row = 5, sticky="nsew")
            self.bus_number_Region2 = tk.Label(self.CanvasFrame, text=str(round(pic.transport_density()[1][0],1)), font = f3, bg = "white")
            self.bus_number_Region2.grid(column = 2, row = 5, sticky="nsew")
            self.bus_number_Region3 = tk.Label(self.CanvasFrame, text=str(round(pic.transport_density()[2][0],1)), font = f3, bg = "white")
            self.bus_number_Region3.grid(column = 3, row = 5, sticky="nsew")
        
            self.clinic_label = tk.Label(self.CanvasFrame, text='人均診所家數(千分之一)', font = f1, bg = "white")
            self.clinic_label.grid(column = 5, row = 3, columnspan = 3, sticky="nsew")
        
            self.clinic_label_Region1 = tk.Label(self.CanvasFrame, text=selected_list[0][1], font = f2, bg = "white")
            self.clinic_label_Region1.grid(column = 5, row = 4, sticky="nsew")
            self.clinic_label_Region2 = tk.Label(self.CanvasFrame, text=selected_list[1][1], font = f2, bg = "white")
            self.clinic_label_Region2.grid(column = 6, row = 4, sticky="nsew")
            self.clinic_label_Region3 = tk.Label(self.CanvasFrame, text=selected_list[2][1], font = f2, bg = "white")
            self.clinic_label_Region3.grid(column = 7, row = 4, sticky="nsew")

            self.clinic_number_Region1 = tk.Label(self.CanvasFrame, text=str(round(pic.clinic_density()[0][0],1)), font = f3, bg = "white")
            self.clinic_number_Region1.grid(column = 5, row = 5, sticky="nsew")
            self.clinic_number_Region2 = tk.Label(self.CanvasFrame, text=str(round(pic.clinic_density()[1][0],1)), font = f3, bg = "white")
            self.clinic_number_Region2.grid(column = 6, row = 5, sticky="nsew")
            self.clinic_number_Region3 = tk.Label(self.CanvasFrame, text=str(round(pic.clinic_density()[2][0],1)), font = f3, bg = "white")
            self.clinic_number_Region3.grid(column = 7, row = 5, sticky="nsew")
        
        # 畫圖
            one = FigureCanvasTkAgg(pic.income_pic(), self.CanvasFrame)
            one.get_tk_widget().grid(column = 1, row = 7, columnspan = 3)
        
            two = FigureCanvasTkAgg(pic.clinic_pic(), self.CanvasFrame)
            two.get_tk_widget().grid(column = 5, row = 7, columnspan = 3)
        
            three = FigureCanvasTkAgg(pic.entertainment_pic(), self.CanvasFrame) 
            three.get_tk_widget().grid(column = 1, row = 9, columnspan = 3)
    
            four = FigureCanvasTkAgg(pic.crime_pic(), self.CanvasFrame)
            four.get_tk_widget().grid(column = 5, row = 9, columnspan = 3)

            five = FigureCanvasTkAgg(pic.school_pic(), self.CanvasFrame)
            five.get_tk_widget().grid(column = 1, row = 11, columnspan = 3)
        
            six = FigureCanvasTkAgg(pic.air_pic(), self.CanvasFrame)
            six.get_tk_widget().grid(column = 5, row = 11, columnspan = 3)
    
        # 建立下拉捲軸
            self.Scroll = tk.Scrollbar(self.Frame, orient=tk.VERTICAL)
            self.Scroll.config(command=self.Canvas.yview)
            self.Canvas.config(yscrollcommand=self.Scroll.set)
            self.Scroll.grid(row=3, column=1, sticky="ns")
            self.CanvasFrame.bind("<Configure>", self.update_scrollregion)

# %% [markdown]
# # 繪圖 class

# %%
class draw():
    
    def __init__(self,lists):
        self.cities = [lists[0][0], lists[1][0],lists[2][0]]          # 處理傳入的lists
        self.regions = [lists[0][1],lists[1][1],lists[2][1]]

        self.income_data =  pd.read_csv('平均家庭收入.csv')    
        self.clinic_data = pd.read_csv('醫療資源.csv')
        self.entertainment_data = pd.read_csv('娛樂.csv')
        self.market_data = pd.read_csv('超市家數.csv')
        self.crime_data = pd.read_csv('犯罪率.csv')
        self.school_data = pd.read_csv('學校數量.csv')
        self.air_data = pd.read_csv('air_pollution.csv')
        self.transport_data = pd.read_csv('公車站牌密度.csv')
        self.title_size = 25
        self.ticks_size = 13
        
    
    def transport_density(self):
        no1 =  self.transport_data[( self.transport_data.loc[:,'地區名'] ==  self.regions[0]) & ( self.transport_data.loc[:,'縣市名'] == self.cities[0])]['公車站牌密度(站/平方公里)']
        y1 = no1.values.flatten()
        no2 = self.transport_data[( self.transport_data.loc[:,'地區名'] ==  self.regions[1]) & ( self.transport_data.loc[:,'縣市名'] == self.cities[1])]['公車站牌密度(站/平方公里)']
        y2 = no2 .values.flatten()
        no3 = self.transport_data[( self.transport_data.loc[:,'地區名'] ==  self.regions[2]) & ( self.transport_data.loc[:,'縣市名'] == self.cities[2])]['公車站牌密度(站/平方公里)']
        y3 = no3.values.flatten()

        return [y1, y2, y3]
    
    
    def clinic_density(self):
        no1 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[0]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[0])]['人均院所家數(家數/千人)']
        y1 = no1.values.flatten()
        no2 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[1]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[1])]['人均院所家數(家數/千人)']
        y2 = no2 .values.flatten()
        no3 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[2]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[2])]['人均院所家數(家數/千人)']
        y3 = no3.values.flatten()
        
        return [y1, y2, y3]
        
       
    def income_pic (self):
        city_list = list(set(self.cities)) + ['臺灣地區']
        F = plt.figure(figsize = (7.1,7.1), dpi = 100)
        x = self.income_data['年份']
        for city in city_list:
            y = self.income_data[city]/(10**6)
            plt.plot(x,y, marker = 'o',label = city)
        plt.title('年收入', fontsize = self.title_size)
        plt.xticks(fontsize = self.ticks_size)
        plt.yticks(fontsize = self.ticks_size)
        plt.ylabel('單位：百萬元', fontsize = self.ticks_size)
        plt.rc('font', family = 'Microsoft-YaHei')
        plt.legend()
        return F


    def clinic_pic(self):
        clinic = ['診所家數', '大醫院家數'] 
        F = plt.figure(figsize=(7.1,7.1), dpi=100)
        no1 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[0]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[0])][clinic]
        x_all = list(range(0, len(clinic)))
        y1 = no1.values.flatten()
        no2 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[1]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[1])][clinic]
        y2 = no2 .values.flatten()
        no3 = self.clinic_data[(self.clinic_data.loc[:,'地區名'] ==  self.regions[2]) & (self.clinic_data.loc[:,'縣市名'] == self.cities[2])][clinic]
        y3 = no3.values.flatten()

        width = 0.25   #先設定每個長條的寬度
        
        plt.barh([i-width for i in x_all], y1, height=width, label= (self.cities[0]+self.regions[0])) #注意這裡的X軸座標為x1中的數據減去寬度的一半
        plt.barh([i for i in x_all], y2, height=width, label=(self.cities[1]+self.regions[1]))        #注意這裡的X軸座標為x1中的數據加上寬度的一半
        plt.barh([i+width for i in x_all], y3, height=width, label=(self.cities[2]+self.regions[2]))
        plt.yticks(x_all,clinic, rotation = 45, fontsize = self.ticks_size)
        plt.xticks(fontsize = self.ticks_size)
        plt.xlabel('單位：間', fontsize = self.ticks_size)
        plt.legend()
        plt.title('醫院診所',fontsize = self.title_size)
        return F


    def entertainment_pic (self):      
        entertainment = ['電影院', '百貨','全聯','頂好','好市多'] 
        F = plt.figure(figsize=(7.1,7.1), dpi=100)
        x_all = list(range(0, len(entertainment)))
        no1 = self.entertainment_data[(self.entertainment_data.loc[:,'地區名'] == self.regions[0]) & (self.entertainment_data.loc[:,'縣市名'] == self.cities[0])][entertainment]
        y1 = no1.values.flatten()
        no2 = self.entertainment_data[(self.entertainment_data.loc[:,'地區名'] == self.regions[1]) & (self.entertainment_data.loc[:,'縣市名'] == self.cities[1])][entertainment]
        y2 = no2 .values.flatten()
        no3 = self.entertainment_data[(self.entertainment_data.loc[:,'地區名'] == self.regions[2]) & (self.entertainment_data.loc[:,'縣市名'] == self.cities[2])][entertainment]
        y3 = no3.values.flatten()
        
        width = 0.25   #先設定每個長條的寬度
        plt.bar([i-width for i in x_all], y1, width=width, label= (self.cities[0]+self.regions[0])) #注意這裡的X軸座標為x1中的數據減去寬度的一半
        plt.bar([i for i in x_all], y2, width=width, label=(self.cities[1]+self.regions[1]))        #注意這裡的X軸座標為x1中的數據加上寬度的一半
        plt.bar([i+width for i in x_all], y3, width=width, label=(self.cities[2]+self.regions[2]))
        plt.xticks(x_all,entertainment, fontsize = self.ticks_size)
        plt.yticks(fontsize = self.ticks_size)
        plt.ylabel('單位：間', fontsize = self.ticks_size)
        plt.legend()
        plt.title('百貨&電影院&超市數目', fontsize = self.title_size)
        return F
        

    def crime_pic (self):
        crime = ['竊盜犯罪率','強制性交犯罪率','強盜犯罪率','搶奪犯罪率']
        ticks_name = ['竊盜','強制性交','強盜','搶奪']
        F = plt.figure(figsize=(7.1,7.1), dpi=100)
        x_all = list(range(0, len(crime )))
        no1 = self.crime_data[(self.crime_data.loc[:,'地區名'] == self.regions[0]) & (self.crime_data.loc[:,'縣市名'] == self.cities[0])][crime]
        y1 = no1.values.flatten()
        no2 = self.crime_data[(self.crime_data.loc[:,'地區名'] == self.regions[1]) & (self.crime_data.loc[:,'縣市名'] == self.cities[1])][crime]
        y2 = no2 .values.flatten()
        no3 = self.crime_data[(self.crime_data.loc[:,'地區名'] == self.regions[2]) & (self.crime_data.loc[:,'縣市名'] == self.cities[2])][crime]
        y3 = no3.values.flatten()
        
        width = 0.25   #先設定每個長條的寬度
        plt.bar([i-width for i in x_all], y1, width=width, label= (self.cities[0]+self.regions[0])) #注意這裡的X軸座標為x1中的數據減去寬度的一半
        plt.bar([i for i in x_all], y2, width=width, label=(self.cities[1]+self.regions[1]))        #注意這裡的X軸座標為x1中的數據加上寬度的一半
        plt.bar([i+width for i in x_all], y3, width=width, label=(self.cities[2]+self.regions[2]))
        plt.xticks(x_all,ticks_name, fontsize = self.ticks_size)
        plt.yticks(fontsize = self.ticks_size)
        plt.ylabel('單位：件/十萬人', fontsize = self.ticks_size)
        plt.legend()
        plt.title('犯罪率（三年加總）', fontsize = self.title_size)
        return F
        

    def school_pic (self):
        school =['幼稚園數量', '國小數量', '國中數量', '高中數量', '大學數量']
        F = plt.figure(figsize=(7.1,7.1), dpi=100)
        x_all = list(range(0, len(school)))
        no1 = self.school_data[(self.school_data.loc[:,'地區名'] == self.regions[0]) & (self.school_data.loc[:,'縣市名'] == self.cities[0])][school]
        y1 = no1.values.flatten()
        no2 = self.school_data[(self.school_data.loc[:,'地區名'] == self.regions[1]) & (self.school_data.loc[:,'縣市名'] == self.cities[1])][school]
        y2 = no2 .values.flatten()
        no3 = self.school_data[(self.school_data.loc[:,'地區名'] == self.regions[2]) & (self.school_data.loc[:,'縣市名'] == self.cities[2])][school]
        y3 = no3.values.flatten()
        
        width = 0.25   #先設定每個長條的寬度
        plt.bar([i-width for i in x_all], y1, width=width, label= (self.cities[0]+self.regions[0])) #注意這裡的X軸座標為x1中的數據減去寬度的一半
        plt.bar([i for i in x_all], y2, width=width, label=(self.cities[1]+self.regions[1]))        #注意這裡的X軸座標為x1中的數據加上寬度的一半
        plt.bar([i+width for i in x_all], y3, width=width, label=(self.cities[2]+self.regions[2]))
        plt.xticks(x_all,school, fontsize = self.ticks_size)
        plt.yticks(fontsize = self.ticks_size)
        plt.ylabel('單位：間', fontsize = self.ticks_size)
        plt.legend()
        plt.title('各級學校數目', fontsize = self.title_size)
        return F
       

    def air_pic (self):
        F = plt.figure(figsize=(7.1,7.1), dpi=100)
        no1 = self.air_data[(self.air_data.loc[:,'地區名'] == self.regions[0]) & (self.air_data.loc[:,'縣市名'] == self.cities[0])]['PM 2.5']
        x1 = list(range(0, 11))
        y1 = no1.values.flatten()
        no2 = self.air_data[(self.air_data.loc[:,'地區名'] == self.regions[1]) & (self.air_data.loc[:,'縣市名'] == self.cities[1])]['PM 2.5']
        y2 = no2 .values.flatten()
        no3 = self.air_data[(self.air_data.loc[:,'地區名'] == self.regions[2]) & (self.air_data.loc[:,'縣市名'] == self.cities[2])]['PM 2.5']
        y3 = no3.values.flatten()
        
        plt.plot(x1,y1, marker = 'o', label = self.cities[0] + self.regions[0])
        plt.plot(x1,y2, marker = 'o', label = self.cities[1] + self.regions[1])
        plt.plot(x1,y3, marker = 'o', label = self.cities[2] + self.regions[2])
        date = [('2019/'+str(x)) for x in range(1,12)]
        plt.xticks(x1,date, rotation = 45, fontsize = self.ticks_size)
        plt.yticks(fontsize = self.ticks_size)
        plt.title('空氣品質', fontsize = self.title_size)
        plt.ylabel('單位：μg/m3', fontsize = self.ticks_size)
        plt.legend()
        return F

# %% [markdown]
# # 主程式區

# %%
# GUI頁面建立
cal = tk.Tk()
cal.title("南波灣住區生活品質檢測")
cal.geometry('1050x700')

# 下拉式選單建立
Design().Drop_down_list("所選地區  : ", 0)
Design().Drop_down_list("比較地區1 : ", 1)
Design().Drop_down_list("比較地區2 : ", 2)

# 搜尋按鈕建立
button = tk.Button(cal, text = "搜尋", bg = "lightblue", command = Design().Search)
button.grid(column = 3, row = 0, rowspan = 3)

cal.mainloop()
# Out:
# [['新北市', '板橋區'], ['連江縣', '莒光鄉'], ['南海島', '南海島']]
# [['新北市', '板橋區'], ['連江縣', '莒光鄉'], ['南海島', '南海島']]
# [['新北市', '板橋區'], ['連江縣', '莒光鄉'], ['嘉義市', '西區']]
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 35199 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from matplotlib.font_manager import _rebuild

_rebuild() #reload一下

# %%
import matplotlib 
matplotlib.matplotlib_fname()
# Out:
# '/Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
from matplotlib.font_manager import FontProperties

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft-YaHei']
plt.rcParams['axes.unicode_minus'] = False
plt.plot((1,2,3),(4,3,-1))
plt.title("聲量圖")
plt.ylabel("文章數量")
plt.xlabel("品牌名稱") 
plt.show()
# Out:
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.
# findfont: Font family ['Microsoft-YaHei'] not found. Falling back to DejaVu Sans.
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 32882 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 29260 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 21517 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 31281 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 29260 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 21517 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 31281 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 25991 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 31456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 25991 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 31456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 32882 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/lanjingyi/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 22294 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft-YaHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
from PIL import Image, ImageTk

# %%
data
# Out:
# {'縣市': '',
#  '臺北市': {'中正區': ['三元街',
#    '中山北路１段',
#    '中山南路',
#    '中華路１段',
#    '中華路２段',
#    '丹陽街',
#    '仁愛路１段',
#    '仁愛路２段',
#    '信義路１段',
#    '信義路２段',
#    '信陽街',
#    '八德路１段',
#    '公園路',
#    '凱達格蘭大道',
#    '北平東路',
#    '北平西路',
#    '南昌路１段',
#    '南昌路２段',
#    '南海路',
#    '南陽街',
#    '博愛路',
#    '同安街',
#    '和平西路１段',
#    '和平西路２段',
#    '大埔街',
#    '天津街',
#    '寧波東街',
#    '寧波西街',
#    '寶慶路',
#    '市民大道１段',
#    '市民大道２段',
#    '市民大道３段',
#    '師大路',
#    '常德街',
#    '廈門街',
#    '廣州街',
#    '延平南路',
#    '徐州路',
#    '忠孝東路１段',
#    '忠孝東路２段',
#    '忠孝西路１段',
#    '思源街',
#    '惠安街',
#    '愛國東路',
#    '愛國西路',
#    '懷寧街',
#    '新生南路１段',
#    '晉江街',
#    '杭州北路',
#    '杭州南路１段',
#    '杭州南路２段',
#    '林森北路',
#    '林森南路',
#    '桃源街',
#    '武昌街１段',
#    '水源路',
#    '永春街',
#    '永綏街',
#    '汀州路１段',
#    '汀州路２段',
#    '汀州路３段',
#    '沅陵街',
#    '泉州街',
#    '泰安街',
#    '湖口街',
#    '漢口街１段',
#    '潮州街',
#    '濟南路１段',
#    '濟南路２段',
#    '牯嶺街',
#    '福州街',
#    '秀山街',
#    '紹興北街',
#    '紹興南街',
#    '羅斯福路１段',
#    '羅斯福路２段',
#    '羅斯福路３段',
#    '羅斯福路４段',
#    '臨沂街',
#    '自強市場第三棟',
#    '莒光路',
#    '衡陽路',
#    '襄陽路',
#    '西藏路',
#    '許昌街',
#    '詔安街',
#    '貴陽街１段',
#    '辛亥路１段',
#    '連雲街',
#    '酉陽街',
#    '重慶南路１段',
#    '重慶南路２段',
#    '重慶南路３段',
#    '金山北路',
#    '金山南路１段',
#    '金華街',
#    '金門街',
#    '銅山街',
#    '鎮江街',
#    '長沙街１段',
#    '開封街１段',
#    '青島東路',
#    '青島西路',
#    '館前路',
#    '齊東街'],
#   '大同區': ['五原路',
#    '伊寧街',
#    '保安街',
#    '南京西路',
#    '哈密街',
#    '塔城街',
#    '大龍街',
#    '天水路',
#    '太原路',
#    '安西街',
#    '寧夏路',
#    '市民大道１段',
#    '平陽街',
#    '庫倫街',
#    '延平北路１段',
#    '延平北路２段',
#    '延平北路３段',
#    '延平北路４段',
#    '忠孝西路２段',
#    '承德路１段',
#    '承德路２段',
#    '承德路３段',
#    '撫順街',
#    '敦煌路',
#    '昌吉街',
#    '景化街',
#    '歸綏街',
#    '民族西路',
#    '民樂街',
#    '民權西路',
#    '民生西路',
#    '永昌街',
#    '涼州街',
#    '環河北路１段',
#    '環河北路２段',
#    '甘州街',
#    '甘谷街',
#    '興城街',
#    '華亭街',
#    '華陰街',
#    '萬全街',
#    '蘭州街',
#    '西寧北路',
#    '貴德街',
#    '赤峰街',
#    '迪化街１段',
#    '迪化街２段',
#    '通河西街１段',
#    '鄭州路',
#    '酒泉街',
#    '重慶北路１段',
#    '重慶北路２段',
#    '重慶北路３段',
#    '錦西街',
#    '長安西路',
#    '雙連街'],
#   '中山區': ['一江街',
#    '中原街',
#    '中山北路１段',
#    '中山北路２段',
#    '中山北路３段',
#    '中山北路４段',
#    '五常街',
#    '伊通街',
#    '內湖路１段',
#    '八德路２段',
#    '劍南路',
#    '北安路',
#    '南京東路１段',
#    '南京東路２段',
#    '南京東路３段',
#    '南京西路',
#    '合江街',
#    '吉林路',
#    '四平街',
#    '基湖路',
#    '堤頂大道２段',
#    '大直街',
#    '天津街',
#    '天祥路',
#    '安東街',
#    '崇實路',
#    '市民大道２段',
#    '市民大道３段',
#    '建國北路１段',
#    '建國北路２段',
#    '建國北路３段',
#    '建國南路１段',
#    '復興北路',
#    '復興南路１段',
#    '德惠街',
#    '撫順街',
#    '敬業一路',
#    '敬業三路',
#    '敬業二路',
#    '敬業四路',
#    '新生北路１段',
#    '新生北路２段',
#    '新生北路３段',
#    '明水路',
#    '朱崙街',
#    '松江路',
#    '林森北路',
#    '植福路',
#    '樂群三路',
#    '樂群二路',
#    '民族東路',
#    '民族西路',
#    '民權東路１段',
#    '民權東路２段',
#    '民權東路３段',
#    '民權西路',
#    '民生東路１段',
#    '民生東路２段',
#    '民生東路３段',
#    '民生西路',
#    '渭水路',
#    '濱江街',
#    '玉門街',
#    '興安街',
#    '華陰街',
#    '農安街',
#    '通北街',
#    '遼寧街',
#    '錦州街',
#    '錦西街',
#    '長安東路１段',
#    '長安東路２段',
#    '長安西路',
#    '長春路',
#    '雙城街',
#    '龍江路'],
#   '松山區': ['三民路',
#    '五常街',
#    '健康路',
#    '光復北路',
#    '光復南路',
#    '八德路２段',
#    '八德路３段',
#    '八德路４段',
#    '北寧路',
#    '南京東路３段',
#    '南京東路４段',
#    '南京東路５段',
#    '吉祥路',
#    '基隆路１段',
#    '塔悠路',
#    '富錦街',
#    '寧安街',
#    '寶清街',
#    '市民大道４段',
#    '市民大道５段',
#    '市民大道６段',
#    '延吉街',
#    '延壽街',
#    '復興北路',
#    '復興南路１段',
#    '慶城街',
#    '撫遠街',
#    '敦化北路',
#    '敦化南路１段',
#    '新中街',
#    '新東街',
#    '東寧路',
#    '東興路',
#    '松山路',
#    '松河街',
#    '民族東路',
#    '民權東路３段',
#    '民權東路４段',
#    '民權東路５段',
#    '民生東路３段',
#    '民生東路４段',
#    '民生東路５段',
#    '濱江街',
#    '興安街',
#    '虎林街',
#    '長安東路２段',
#    '長春路',
#    '饒河街'],
#   '大安區': ['仁愛路３段',
#    '仁愛路４段',
#    '信義路２段',
#    '信義路３段',
#    '信義路４段',
#    '光復南路',
#    '八德路２段',
#    '和平東路１段',
#    '和平東路２段',
#    '和平東路３段',
#    '嘉興街',
#    '四維路',
#    '基隆路２段',
#    '基隆路３段',
#    '基隆路４段',
#    '大安路１段',
#    '大安路２段',
#    '安和路１段',
#    '安和路２段',
#    '安居街',
#    '安東街',
#    '富陽街',
#    '市民大道３段',
#    '市民大道４段',
#    '師大路',
#    '延吉街',
#    '建國南路１段',
#    '建國南路２段',
#    '復興南路１段',
#    '復興南路２段',
#    '忠孝東路３段',
#    '忠孝東路４段',
#    '愛國東路',
#    '敦化南路１段',
#    '敦化南路２段',
#    '敦南街',
#    '文昌街',
#    '新生北路１段',
#    '新生南路１段',
#    '新生南路２段',
#    '新生南路３段',
#    '杭州南路２段',
#    '東豐街',
#    '樂利路',
#    '樂業街',
#    '永康街',
#    '泰順街',
#    '浦城街',
#    '溫州街',
#    '潮州街',
#    '濟南路３段',
#    '瑞安街',
#    '羅斯福路２段',
#    '羅斯福路３段',
#    '羅斯福路４段',
#    '臥龍街',
#    '臨江街',
#    '芳蘭路',
#    '辛亥路１段',
#    '辛亥路２段',
#    '辛亥路３段',
#    '通化街',
#    '通安街',
#    '金山南路２段',
#    '金華街',
#    '長興街',
#    '雲和街',
#    '青田街',
#    '麗水街',
#    '龍泉街'],
#   '萬華區': ['三水街',
#    '中華路１段',
#    '中華路２段',
#    '內江街',
#    '南寧路',
#    '和平西路２段',
#    '和平西路３段',
#    '國興路',
#    '大埔街',
#    '大理街',
#    '富民路',
#    '寶興街',
#    '峨眉街',
#    '康定路',
#    '廣州街',
#    '德昌街',
#    '忠孝西路２段',
#    '成都路',
#    '昆明街',
#    '東園街',
#    '柳州街',
#    '桂林路',
#    '梧州街',
#    '武成街',
#    '武昌街２段',
#    '民和街',
#    '水源路',
#    '永福街',
#    '汀州路１段',
#    '洛陽街',
#    '漢中街',
#    '漢口街２段',
#    '環河南路１段',
#    '環河南路２段',
#    '環河南路３段',
#    '興寧街',
#    '興義街',
#    '艋舺大道',
#    '莒光路',
#    '華西街',
#    '萬大路',
#    '萬青街',
#    '西園路１段',
#    '西園路２段',
#    '西寧南路',
#    '西昌街',
#    '西藏路',
#    '貴陽街２段',
#    '長沙街２段',
#    '長泰街',
#    '長順街',
#    '開封街２段',
#    '隆昌街',
#    '雅江街',
#    '雙和街',
#    '雙園街',
#    '青年路'],
#   '信義區': ['中坡北路',
#    '中坡南路',
#    '仁愛路４段',
#    '信安街',
#    '信義路４段',
#    '信義路５段',
#    '信義路６段',
#    '光復南路',
#    '吳興街',
#    '和平東路３段',
#    '嘉興街',
#    '基隆路１段',
#    '基隆路２段',
#    '大道路',
#    '富陽街',
#    '崇德街',
#    '市府路',
#    '市民大道５段',
#    '市民大道６段',
#    '忠孝東路４段',
#    '忠孝東路５段',
#    '文昌街',
#    '景雲街',
#    '東興路',
#    '松仁路',
#    '松信路',
#    '松勇路',
#    '松勤街',
#    '松壽路',
#    '松山路',
#    '松平路',
#    '松廉路',
#    '松德路',
#    '松智路',
#    '松隆路',
#    '松高路',
#    '林口街',
#    '永吉路',
#    '瑞雲街',
#    '祥雲街',
#    '福德街',
#    '紫雲街',
#    '莊敬路',
#    '菸廠路',
#    '虎林街',
#    '逸仙路',
#    '青雲街'],
#   '士林區': ['下樹林街',
#    '中山北路４段',
#    '中山北路５段',
#    '中山北路６段',
#    '中山北路７段',
#    '中庸一路',
#    '中庸二路',
#    '中庸五路',
#    '中正路',
#    '中社路１段',
#    '中社路２段',
#    '中興街',
#    '中華路',
#    '仁民路',
#    '仰德大道１段',
#    '仰德大道２段',
#    '仰德大道３段',
#    '仰德大道４段',
#    '倫等街',
#    '光華路',
#    '克強路',
#    '凱旋路',
#    '前港街',
#    '前街',
#    '劍南路',
#    '劍潭路',
#    '力行街',
#    '和平路',
#    '和豐街',
#    '國泰街',
#    '基河路',
#    '士商路',
#    '士東路',
#    '大亨路',
#    '大光街',
#    '大北路',
#    '大南路',
#    '大東路',
#    '大西路',
#    '天母北路',
#    '天母東路',
#    '天母西路',
#    '天玉街',
#    '安平街',
#    '小北街',
#    '小南街',
#    '小東街',
#    '小西街',
#    '平菁街',
#    '幸福街',
#    '延平北路５段',
#    '延平北路６段',
#    '延平北路７段',
#    '延平北路８段',
#    '延平北路９段',
#    '建業路',
#    '後港街',
#    '後街',
#    '德行東路',
#    '德行西路',
#    '志成街',
#    '忠勇街',
#    '忠義街',
#    '忠誠路１段',
#    '忠誠路２段',
#    '愛富一街',
#    '愛富三街',
#    '愛富三街長生巷',
#    '愛富二街',
#    '愛富二街厚生巷',
#    '愛富二街樂生巷',
#    '承德路４段',
#    '承德路５段',
#    '故宮路',
#    '文昌路',
#    '文林路',
#    '新園街',
#    '新安路',
#    '明溪街',
#    '東山路',
#    '格致路',
#    '永公路',
#    '永平街',
#    '環河北路３段',
#    '磺溪街',
#    '社中街',
#    '社子街',
#    '社正路',
#    '福國路',
#    '福壽街',
#    '福德路',
#    '福志路',
#    '福林路',
#    '福榮街',
#    '福港街',
#    '福華路',
#    '竹子湖路',
#    '美崙街',
#    '美德街',
#    '翠山街',
#    '臨溪路',
#    '自祥街',
#    '至善路１段',
#    '至善路２段',
#    '至善路３段',
#    '至誠路１段',
#    '至誠路２段',
#    '芝玉路１段',
#    '芝玉路２段',
#    '莊頂路',
#    '菁山路',
#    '華光街',
#    '華岡路',
#    '華榮街',
#    '華聲街',
#    '華興街',
#    '華齡街',
#    '葫東街',
#    '葫蘆街',
#    '貴富街',
#    '通河東街１段',
#    '通河東街２段',
#    '通河街',
#    '通河西街１段',
#    '通河西街２段',
#    '重慶北路４段',
#    '長春街',
#    '陽明路１段',
#    '陽明路２段',
#    '雙溪街',
#    '雨聲街',
#    '雨農路'],
#   '北投區': ['一德街',
#    '一心路',
#    '七星街',
#    '三合街１段',
#    '三合街２段',
#    '中和街',
#    '中和街新建巷',
#    '中和街錫安巷',
#    '中央北路１段',
#    '中央北路２段',
#    '中央北路３段',
#    '中央北路４段',
#    '中央南路１段',
#    '中央南路２段',
#    '中山北路７段',
#    '中山路',
#    '中心街',
#    '中正街',
#    '中興路',
#    '中華街',
#    '光明路',
#    '光明路新生巷',
#    '公舘路',
#    '勝利街',
#    '北投路１段',
#    '北投路２段',
#    '吉利街',
#    '同德街',
#    '大同街',
#    '大屯路',
#    '大屯路光華一巷',
#    '大屯路光華三巷',
#    '大屯路光華二巷',
#    '大屯路光華四巷',
#    '大度路',
#    '大度路怡和巷',
#    '大度路３段',
#    '大業路',
#    '大興街',
#    '天母北路',
#    '天母西路',
#    '奇岩路',
#    '奉賢路',
#    '學園路',
#    '宜山路',
#    '富貴一路',
#    '實踐街',
#    '尊賢街',
#    '崇仁路１段',
#    '崇仰一路',
#    '崇仰七路',
#    '崇仰三路',
#    '崇仰九路',
#    '崇仰二路',
#    '崇仰五路',
#    '崇仰六路',
#    '崗山路',
#    '幽雅路',
#    '幽雅路杏林巷',
#    '建國街',
#    '建民路',
#    '復興一路',
#    '復興三路',
#    '復興二路',
#    '復興四路',
#    '懷德街',
#    '承德路６段',
#    '承德路７段',
#    '振興街',
#    '振華街',
#    '文化三路',
#    '文林北路',
#    '新市街',
#    '新民路',
#    '新民路康樂巷',
#    '新民路香丘巷',
#    '新生街',
#    '新興路',
#    '明德路',
#    '杏林一路',
#    '杏林三路',
#    '杏林二路',
#    '東昇路',
#    '東華街１段',
#    '東華街２段',
#    '東陽街',
#    '榮華一路',
#    '榮華三路',
#    '榮華二路',
#    '樹林路',
#    '民族街',
#    '民權街',
#    '永興路１段',
#    '永興路２段',
#    '泉源路',
#    '泉源路華南巷',
#    '洲美街',
#    '清江路',
#    '湖山路１段',
#    '湖山路２段',
#    '湖底路',
#    '溫泉路',
#    '溫泉路天主巷',
#    '溫泉路湯元巷',
#    '溫泉路銀光巷',
#    '珠海路',
#    '登山路',
#    '知行路',
#    '石仙路',
#    '石牌路１段',
#    '石牌路２段',
#    '磺港路',
#    '福美路',
#    '秀山路',
#    '稻香路',
#    '立功街',
#    '立德路',
#    '立賢路',
#    '立農街１段',
#    '立農街２段',
#    '竹子湖路',
#    '紗帽路',
#    '義方街',
#    '義理街',
#    '翠宜路',
#    '翠嶺路',
#    '翠華街',
#    '翠雲街',
#    '聖景路',
#    '育仁路',
#    '自強街',
#    '致遠一路１段',
#    '致遠一路２段',
#    '致遠三路',
#    '致遠二路',
#    '行義路',
#    '裕民一路',
#    '裕民三路',
#    '裕民二路',
#    '裕民六路',
#    '裕民四路',
#    '西園街',
#    '西安街１段',
#    '西安街２段',
#    '豐年路１段',
#    '豐年路２段',
#    '進賢路',
#    '重三路',
#    '長壽路',
#    '開明街',
#    '關渡路',
#    '陽明路１段',
#    '陽明路２段',
#    '雙全街'],
#   '內湖區': ['五分街',
#    '內湖路１段',
#    '內湖路２段',
#    '內湖路３段',
#    '南京東路６段',
#    '基湖路',
#    '堤頂大道１段',
#    '堤頂大道２段',
#    '大湖山莊街',
#    '大湖街',
#    '安康路',
#    '安泰街',
#    '安美街',
#    '康寧路１段',
#    '康寧路３段',
#    '康樂街',
#    '康湖路',
#    '成功路２段',
#    '成功路３段',
#    '成功路４段',
#    '成功路５段',
#    '文德路',
#    '文湖街',
#    '新富街',
#    '新明路',
#    '新湖一路',
#    '新湖三路',
#    '新湖二路',
#    '新豐街',
#    '星雲街',
#    '東湖路',
#    '民善街',
#    '民權東路６段',
#    '永保街',
#    '江南街',
#    '洲子街',
#    '港墘路',
#    '港華街',
#    '潭美街',
#    '瑞光路',
#    '瑞湖街',
#    '環山路１段',
#    '環山路２段',
#    '環山路３段',
#    '石潭路',
#    '碧山路',
#    '舊宗路１段',
#    '舊宗路２段',
#    '行善路',
#    '行忠路',
#    '行愛路',
#    '金湖路',
#    '金莊路',
#    '金豐街',
#    '金龍路',
#    '陽光街',
#    '麗山街'],
#   '南港區': ['三重路',
#    '中南街',
#    '中坡北路',
#    '中坡南路',
#    '八德路４段',
#    '南深路',
#    '南港路１段',
#    '南港路２段',
#    '南港路３段',
#    '合順街',
#    '同德路',
#    '向陽路',
#    '園區街',
#    '富康街',
#    '市民大道７段',
#    '市民大道８段',
#    '忠孝東路５段',
#    '忠孝東路６段',
#    '忠孝東路７段',
#    '惠民街',
#    '成功路１段',
#    '成福路',
#    '新民街',
#    '昆陽街',
#    '東南街',
#    '東新街',
#    '東明街',
#    '松河街',
#    '永吉路',
#    '港東街',
#    '玉成街',
#    '研究院路１段',
#    '研究院路２段',
#    '研究院路３段',
#    '研究院路４段',
#    '福山街',
#    '福德街',
#    '經園街',
#    '經貿一路',
#    '經貿二路',
#    '興中路',
#    '興南街',
#    '興東街',
#    '興華路',
#    '舊莊街１段',
#    '舊莊街２段',
#    '重陽路'],
#   '文山區': ['一壽街',
#    '三福街',
#    '下崙路',
#    '中崙路',
#    '久康街',
#    '仙岩路',
#    '保儀路',
#    '光輝路',
#    '公館街',
#    '和平東路４段',
#    '和興路',
#    '富山路',
#    '忠順街１段',
#    '忠順街２段',
#    '恆光街',
#    '指南路１段',
#    '指南路２段',
#    '指南路３段',
#    '政大一街',
#    '政大三街',
#    '政大二街',
#    '新光路１段',
#    '新光路２段',
#    '景中街',
#    '景仁街',
#    '景後街',
#    '景文街',
#    '景明街',
#    '景福街',
#    '景美街',
#    '景興路',
#    '景華街',
#    '景豐街',
#    '景隆街',
#    '木新路２段',
#    '木新路３段',
#    '木柵路１段',
#    '木柵路２段',
#    '木柵路３段',
#    '木柵路４段',
#    '木柵路５段',
#    '樟新街',
#    '永安街',
#    '汀州路４段',
#    '溪口街',
#    '溪洲街',
#    '福興路',
#    '秀明路１段',
#    '秀明路２段',
#    '羅斯福路４段',
#    '羅斯福路５段',
#    '羅斯福路６段',
#    '老泉街',
#    '育英街',
#    '興德路',
#    '興隆路１段',
#    '興隆路２段',
#    '興隆路３段',
#    '興隆路４段',
#    '興順街',
#    '萬利街',
#    '萬和街',
#    '萬壽路',
#    '萬安街',
#    '萬寧街',
#    '萬慶街',
#    '萬盛街',
#    '萬美街１段',
#    '萬美街２段',
#    '萬芳路',
#    '萬隆街',
#    '試院路',
#    '車前路',
#    '辛亥路４段',
#    '辛亥路５段',
#    '辛亥路６段',
#    '辛亥路７段',
#    '開元街',
#    '集英街']},
#  '基隆市': {'仁愛區': ['仁一路',
#    '仁三路',
#    '仁二路',
#    '仁五路',
#    '仁四路',
#    '光一路',
#    '光二路',
#    '公園街',
#    '劉銘傳路',
#    '南新街',
#    '南榮路',
#    '孝一路',
#    '孝三路',
#    '孝二路',
#    '孝四路',
#    '崇安街',
#    '延平街',
#    '復興街',
#    '忠一路',
#    '忠三路',
#    '忠二路',
#    '忠四路',
#    '愛一路',
#    '愛七路',
#    '愛三路',
#    '愛九路',
#    '愛二路',
#    '愛五路',
#    '愛六路',
#    '愛四路',
#    '成功一路',
#    '曲水街',
#    '港西街',
#    '獅球路',
#    '精一路',
#    '自來街',
#    '華一街',
#    '華三街',
#    '華二街',
#    '華五街',
#    '華六街',
#    '華四街',
#    '龍安街'],
#   '信義區': ['中興路',
#    '仁一路',
#    '信一路',
#    '信二路',
#    '六和街',
#    '培德路',
#    '壽山路',
#    '孝東路',
#    '崇法街',
#    '教孝街',
#    '教忠街',
#    '月眉路',
#    '東信路',
#    '東光路',
#    '東峰街',
#    '東明路',
#    '東美一街',
#    '東美二街',
#    '正信路',
#    '深溪路',
#    '深澳坑路',
#    '深美街',
#    '福民街',
#    '義七路',
#    '義三路',
#    '義九路',
#    '義五路',
#    '義六路',
#    '義四路',
#    '花源一街',
#    '花源一街地下層店鋪',
#    '花源七街',
#    '花源三街',
#    '花源九街',
#    '花源五街'],
#   '中正區': ['中正路',
#    '中船路',
#    '信一路',
#    '信七路',
#    '信三路',
#    '信二路',
#    '信五路',
#    '信六路',
#    '信四路',
#    '八斗街',
#    '北寧路',
#    '和一路',
#    '和二路',
#    '和平街',
#    '基隆嶼',
#    '平一路',
#    '平三路',
#    '平二路',
#    '彭佳嶼',
#    '新豐街',
#    '東海街',
#    '棉花嶼',
#    '正榮街',
#    '正濱路',
#    '正義路',
#    '正豐街',
#    '武昌街',
#    '漁港一街',
#    '漁港三街',
#    '漁港二街',
#    '環港街',
#    '祥豐街',
#    '立德路',
#    '義一路',
#    '義三路',
#    '義二路',
#    '花瓶嶼',
#    '觀海街',
#    '調和街',
#    '豐稔街'],
#   '中山區': ['中和路',
#    '中山一路',
#    '中山三路',
#    '中山二路',
#    '中山四路',
#    '中平街',
#    '中華路',
#    '仁安街',
#    '仙洞街',
#    '健民街',
#    '光華路',
#    '協和街',
#    '太白街',
#    '安一路',
#    '復旦路',
#    '復興路',
#    '德安路',
#    '成功二路',
#    '文化路',
#    '文明路',
#    '新民路',
#    '新生路',
#    '湖海路１段',
#    '華興街',
#    '西定路',
#    '通仁街',
#    '通明街'],
#   '安樂區': ['內寮路',
#    '八德路',
#    '基金一路',
#    '基金三路',
#    '基金二路',
#    '安一路',
#    '安和一街',
#    '安和二街',
#    '安樂路１段',
#    '安樂路２段',
#    '定國街',
#    '崇德路',
#    '新西街',
#    '樂一路',
#    '樂利三街',
#    '樂利二街',
#    '武崙街',
#    '武嶺街',
#    '武聖街',
#    '武訓街',
#    '武隆街',
#    '湖海路２段',
#    '麥金路'],
#   '暖暖區': ['八堵路',
#    '國安路',
#    '寧靜街',
#    '尚仁街',
#    '暖中路',
#    '暖暖街',
#    '暖碇路',
#    '東勢街',
#    '東碇路',
#    '水源路',
#    '源遠路',
#    '碇內街',
#    '興隆街',
#    '過港路',
#    '金山街',
#    '金華街'],
#   '七堵區': ['三合街',
#    '俊德街',
#    '俊賢路',
#    '光明路',
#    '八德路',
#    '六堵一街',
#    '六堵二街',
#    '南光街',
#    '南興路',
#    '堵南街',
#    '大同街',
#    '大德路',
#    '大成街',
#    '大華一路',
#    '大華三路',
#    '大華二路',
#    '實踐路',
#    '崇信街',
#    '崇孝街',
#    '崇廉街',
#    '崇智街',
#    '崇禮街',
#    '崇義街',
#    '工建北路',
#    '工建南路',
#    '工建西路',
#    '工建路',
#    '工東街',
#    '明德一路',
#    '明德三路',
#    '明德二路',
#    '東新街',
#    '永富路',
#    '泰和街',
#    '泰安路',
#    '溪頭街',
#    '百一街',
#    '百七街',
#    '百三街',
#    '百二街',
#    '百五街',
#    '百六街',
#    '福一街',
#    '福三街',
#    '福二街',
#    '福五街',
#    '福六街',
#    '綠葉街',
#    '自強路',
#    '自治北街',
#    '自治街',
#    '華新一路',
#    '華新二路',
#    '長安街',
#    '開元路',
#    '麗景一街',
#    '麗景二街']},
#  '新北市': {'萬里區': ['下社',
#    '中福',
#    '二坪',
#    '仁一街',
#    '仁七街',
#    '仁三街',
#    '仁二街',
#    '仁五街',
#    '仁六街',
#    '仁四街',
#    '光宇一路',
#    '光宇三路',
#    '光宇二路',
#    '光宇大道',
#    '內中福',
#    '內崁',
#    '八斗',
#    '公舘崙',
#    '員潭',
#    '坑頭',
#    '坪頂',
#    '大中山',
#    '大仁路',
#    '大勇路',
#    '大坪',
#    '大湖',
#    '太和',
#    '孝一街',
#    '孝七街',
#    '孝三街',
#    '孝二街',
#    '孝五街',
#    '孝六街',
#    '孝四街',
#    '富士坪',
#    '崁脚',
#    '忠一街',
#    '忠三街',
#    '忠二街',
#    '忠五街',
#    '忠六街',
#    '忠四街',
#    '愛一街',
#    '愛三街',
#    '愛二街',
#    '成功新邨',
#    '挹翠路',
#    '新墾丁路',
#    '日光路',
#    '景美',
#    '東澳',
#    '海景路',
#    '清水',
#    '港東',
#    '港東新邨',
#    '港西',
#    '溪底',
#    '漁澳',
#    '烏𡍼炭',
#    '獅頭',
#    '玉田',
#    '瑞泉',
#    '瑪鋉下街',
#    '瑪鋉路',
#    '瑪鋉頂街',
#    '皷亭',
#    '石角',
#    '磺溪',
#    '福德坑',
#    '美崙',
#    '翡翠路',
#    '聽濤路',
#    '萬里加投',
#    '豊𢊬',
#    '達天',
#    '頂社',
#    '香員林',
#    '麗水'],
#   '金山區': ['三民街',
#    '三界壇路',
#    '三重橋',
#    '下六股',
#    '中信北路',
#    '中信南路',
#    '中山路',
#    '中山路新市場',
#    '中正路',
#    '中興路',
#    '中華路',
#    '仁愛路',
#    '信義路',
#    '倒照湖',
#    '八德街',
#    '八煙',
#    '公園路',
#    '六股林口',
#    '半嶺',
#    '南勢',
#    '南勢湖',
#    '名流路',
#    '和平街',
#    '四維路',
#    '坑子內',
#    '大孔尾',
#    '大水堀',
#    '尖山子',
#    '山城路',
#    '市場內',
#    '忠孝一路',
#    '忠義路',
#    '慈護街',
#    '文化一路',
#    '文化三路',
#    '文化二路',
#    '新市場',
#    '曲尺坑',
#    '月眉',
#    '林口',
#    '民生路',
#    '法鼓路',
#    '海興路',
#    '清水路',
#    '溫泉路',
#    '潭子內',
#    '濆水',
#    '焿子坪',
#    '牛埔子',
#    '玉爐路',
#    '環金路',
#    '磺清路',
#    '磺港路',
#    '磺溪頭',
#    '社寮',
#    '福德街',
#    '秀峰坪',
#    '竹子山腳',
#    '自強路',
#    '茅埔頭',
#    '葵扇湖',
#    '西勢',
#    '西勢湖',
#    '跳石',
#    '金包里街',
#    '金包里街舊市場',
#    '金美街',
#    '青年路',
#    '頂六股',
#    '香菓園',
#    '龜子山'],
#   '板橋區': ['三民路１段',
#    '三民路２段',
#    '三民路２段居仁巷',
#    '三民路２段正泰七巷',
#    '三民路２段正泰三巷',
#    '三民路２段正泰二巷',
#    '三民路２段正泰五巷',
#    '三民路２段正泰六巷',
#    '三民路２段正泰四巷',
#    '三民路２段正隆巷',
#    '中山路１段',
#    '中山路２段',
#    '中山路２段光榮巷',
#    '中正路',
#    '中興路',
#    '互助街',
#    '五權街',
#    '仁化街',
#    '仁愛路',
#    '介壽街',
#    '信義路',
#    '倉後街',
#    '僑中一街',
#    '僑中三街',
#    '僑中二街',
#    '光復街',
#    '光明街',
#    '光正街',
#    '光武街',
#    '光環路１段',
#    '光環路２段',
#    '光華街',
#    '公園街',
#    '公館街',
#    '北門街',
#    '區運路',
#    '南興路',
#    '南門街',
#    '南雅南路１段',
#    '南雅南路２段',
#    '南雅東路',
#    '南雅西路１段',
#    '南雅西路２段',
#    '博愛街',
#    '合安一路',
#    '合安路',
#    '合宜一路',
#    '合宜路',
#    '吳鳳路',
#    '和平路',
#    '和平路安樂巷',
#    '四川路１段',
#    '四川路２段',
#    '四川路２段橋頭',
#    '四川路２段橋頭一巷',
#    '四維路',
#    '國光路',
#    '國慶路',
#    '國泰街',
#    '大仁街',
#    '大勇街',
#    '大同街',
#    '大明街',
#    '大智街',
#    '大東街',
#    '大漢街',
#    '大華街',
#    '大華街居安巷',
#    '大觀路１段',
#    '大觀路２段',
#    '大觀路２段力行三巷',
#    '大觀路３段',
#    '大豐街',
#    '太和街',
#    '存德街',
#    '宏國路',
#    '宮口街',
#    '富山街',
#    '實踐路',
#    '干城路',
#    '幸福路',
#    '府中路',
#    '府後街',
#    '廣和街',
#    '廣權路',
#    '建國街',
#    '後埔街',
#    '後菜園街',
#    '復興街',
#    '德興街',
#    '忠孝路',
#    '忠孝路忠義巷',
#    '懷仁街',
#    '懷德街',
#    '成功路',
#    '成都街',
#    '文化路１段',
#    '文化路２段',
#    '文德路',
#    '文新路',
#    '文昌街',
#    '文聖街',
#    '文華街',
#    '新崑路',
#    '新府路',
#    '新月一街',
#    '新月三街',
#    '新月二街',
#    '新民街',
#    '新海路',
#    '新生街',
#    '新站路',
#    '新興路',
#    '明德街',
#    '景福路',
#    '智樂路',
#    '東興街',
#    '東門街',
#    '松柏街',
#    '松江街',
#    '板城路',
#    '板新路',
#    '板林路',
#    '林園街',
#    '林森街',
#    '校前街',
#    '樂群路',
#    '正義街',
#    '民享街',
#    '民安街',
#    '民族路',
#    '民有街',
#    '民權路',
#    '民治街',
#    '民生路１段',
#    '民生路２段',
#    '民生路３段',
#    '永翠路',
#    '永豐街',
#    '江寧路３段',
#    '沙崙街',
#    '海山路',
#    '溪北路',
#    '溪城路',
#    '溪崑一街',
#    '溪崑二街',
#    '溪頭街',
#    '滿平二街',
#    '滿平街',
#    '漢生東路',
#    '漢生西路',
#    '瑞安街',
#    '環河西路４段',
#    '環河西路５段',
#    '環河路',
#    '田單街',
#    '福德街',
#    '稚暉街',
#    '站前路',
#    '篤行路１段',
#    '篤行路２段',
#    '篤行路３段',
#    '篤行路３段玉平巷',
#    '綠堤街',
#    '縣民大道１段',
#    '縣民大道２段',
#    '縣民大道３段',
#    '翠華街',
#    '自強新村',
#    '自由路',
#    '英士路',
#    '茶館街',
#    '莊崑路',
#    '莊敬路',
#    '莒光路',
#    '華東街',
#    '華江一路',
#    '華江七路',
#    '華江三路',
#    '華江九路',
#    '華江二路',
#    '華江五路',
#    '華江八路',
#    '華江六路',
#    '華福街',
#    '華興街',
#    '萬安街',
#    '萬板路',
#    '藝文二街',
#    '藝文街',
#    '裕民街',
#    '西門街',
#    '觀光街',
#    '貴興路',
#    '遠東路',
#    '重慶路',
#    '金華街',
#    '金門街',
#    '銘傳街',
#    '長壽一街',
#    '長壽三街',
#    '長壽二街',
#    '長壽街',
#    '長安街',
#    '長江路１段',
#    '長江路２段',
#    '長江路３段',
#    '防汛路',
#    '陽明街',
#    '雙十路１段',
#    '雙十路２段',
#    '雙十路３段',
#    '雨農路',
#    '館前東路',
#    '館前西路',
#    '館前西路興義巷',
#    '香社一路',
#    '香社二路',
#    '高爾富路',
#    '龍泉街',
#    '龍興街'],
#   '汐止區': ['三民街',
#    '中正路',
#    '中興路',
#    '中華街',
#    '仁愛路',
#    '伯爵街',
#    '保一街',
#    '保新街',
#    '保長路',
#    '信義路',
#    '光復街',
#    '光明街',
#    '內曾路',
#    '八連路１段',
#    '八連路２段',
#    '八連路３段',
#    '公園路',
#    '力行街',
#    '勤進路',
#    '南勢街',
#    '南昌街',
#    '南興路',
#    '南陽街',
#    '原興路',
#    '合順街',
#    '吉林街',
#    '吉祥街',
#    '同德巷',
#    '和平街',
#    '國興街',
#    '夢湖路',
#    '大同路１段',
#    '大同路２段',
#    '大同路３段',
#    '大安街',
#    '姜子寮路',
#    '宜興街',
#    '小坑路',
#    '山光路',
#    '工建路',
#    '康寧街',
#    '建成路',
#    '弘道街',
#    '復興路',
#    '忠一街',
#    '忠三街',
#    '忠二街',
#    '忠孝東路',
#    '招商街',
#    '新台五路１段',
#    '新台五路２段',
#    '新昌路',
#    '新江北路',
#    '新興路',
#    '明峰街',
#    '東勢街',
#    '東山路',
#    '林森街',
#    '樟樹一路',
#    '樟樹二路',
#    '橋東街',
#    '橫科路',
#    '民族一街',
#    '民族三街',
#    '民族二街',
#    '民族五街',
#    '民族六街',
#    '民權街１段',
#    '民權街２段',
#    '民生街',
#    '水源路１段',
#    '水源路２段',
#    '水碓街',
#    '永春一路',
#    '永春二路',
#    '汐平路１段',
#    '汐平路２段',
#    '汐碇路',
#    '汐科路',
#    '汐萬路１段',
#    '汐萬路２段',
#    '汐萬路３段',
#    '湖前街',
#    '湖東街',
#    '瑞松街',
#    '環山路',
#    '環河街',
#    '白雲路',
#    '石壁',
#    '祥雲街',
#    '福安街',
#    '福山街',
#    '福德一路',
#    '福德三路',
#    '福德二路',
#    '福德路',
#    '禮門街',
#    '秀山路',
#    '秀峰路',
#    '翠峰街',
#    '芳園街',
#    '茄安路',
#    '茄福街',
#    '茄興街',
#    '茄苳路',
#    '莊敬街',
#    '連峰街',
#    '連興街',
#    '鄉友街',
#    '鄉長路１段',
#    '鄉長路２段',
#    '長安路',
#    '長江街',
#    '長興街１段',
#    '長興街２段',
#    '長青路',
#    '青山路',
#    '鮕鮘坑街',
#    '鵠鵠崙路',
#    '龍安路'],
#   '深坑區': ['公舘後',
#    '北深路１段',
#    '北深路２段',
#    '北深路３段',
#    '南邦寮',
#    '向天湖',
#    '土庫尖路',
#    '埔新街',
#    '大坪街',
#    '大崙尾',
#    '大崙脚',
#    '平埔街',
#    '文化街',
#    '文山路１段',
#    '文山路２段',
#    '文山路３段',
#    '旺躭路',
#    '昇高坑路',
#    '松柏街',
#    '梘腳坑',
#    '深南路',
#    '深坑街',
#    '炮子崙',
#    '烏月路',
#    '王軍寮',
#    '福音山莊',
#    '紅葉街',
#    '翠谷街',
#    '萬福路',
#    '阿柔洋',
#    '雲鄉路',
#    '風格街'],
#   '石碇區': ['上橫坪',
#    '下橫坪',
#    '下紙寮坑',
#    '中楒仔腳',
#    '串空湖',
#    '九寮子埔',
#    '九芎坑',
#    '二格路',
#    '光明路',
#    '光明路九𡒸坪巷',
#    '光明路耳空龜巷',
#    '光明路頂𥿄寮坑巷',
#    '內楒仔腳',
#    '八分寮',
#    '冷飯坑',
#    '北宜路４段',
#    '北宜路４段栳寮巷',
#    '北宜路５段',
#    '北宜路５段五郎寮巷',
#    '北宜路５段十股寮巷',
#    '北宜路５段土巷',
#    '北宜路５段坑內巷',
#    '北宜路５段大湖巷',
#    '北宜路５段崙尾寮巷',
#    '北宜路５段潭腰巷',
#    '北宜路５段濕水子巷',
#    '北宜路５段火燒樟巷',
#    '北宜路５段竹坑巷',
#    '北宜路５段雷公坡巷',
#    '北宜路６段十三股巷',
#    '北宜路６段塗潭巷',
#    '北宜路６段小金瓜寮巷',
#    '北宜路６段柑腳巷',
#    '北宜路６段水底寮巷',
#    '北宜路６段獅仔頭坑巷',
#    '北宜路６段直潭巷',
#    '十八重溪',
#    '半路店',
#    '南勢坑',
#    '吊橋',
#    '員山子',
#    '員潭子坑',
#    '四分子路',
#    '四分子路小粗坑巷',
#    '外按',
#    '外楒仔腳',
#    '大崙',
#    '大格門',
#    '大湖格',
#    '大溪墘',
#    '天車',
#    '小粗坑',
#    '峯頭',
#    '崩山',
#    '後坑子',
#    '排寮',
#    '文山路１段',
#    '新興坑',
#    '月扇湖',
#    '楓子林',
#    '樟空子',
#    '模乳巷',
#    '橫坪',
#    '深按',
#    '湳子',
#    '湳窟',
#    '溪邊寮',
#    '火燒樟',
#    '烏塗窟',
#    '玉桂嶺',
#    '番子坑',
#    '石崁',
#    '石汐路',
#    '石碇子埔',
#    '石碇東街',
#    '石碇西街',
#    '碇南路２段',
#    '碇南路２段松柏崎巷',
#    '碇南路２段鹿窟巷',
#    '碇坪路１段',
#    '碇坪路２段',
#    '碇格路２段',
#    '磨石坑',
#    '華梵路',
#    '蓬菜寮',
#    '藤寮坑',
#    '蚯蚓坑',
#    '蛇舌子',
#    '西勢坑',
#    '雙溪',
#    '靜安路１段'],
#   '瑞芳區': ['一坑路',
#    '三爪子坑路',
#    '三爪子坑路國中新邨',
#    '三爪子坑路正貿新村',
#    '三爪子坑路民享新村',
#    '中坑路',
#    '中央路',
#    '中央路四十八巷吉祥園',
#    '中山巷',
#    '中山路',
#    '中正路',
#    '九芎橋路',
#    '五號路',
#    '佛堂巷',
#    '侯硐路',
#    '八分寮路',
#    '八號巷',
#    '半嶺路',
#    '南雅路',
#    '台電新邨',
#    '員山子路',
#    '員山子路員山巷',
#    '哩咾路',
#    '四腳亭坑路',
#    '四腳亭埔路',
#    '坑子內路',
#    '坑尾巷',
#    '基山街',
#    '大別莊',
#    '大埔路',
#    '大埔路台北新城',
#    '大埔路吉慶公園城',
#    '大埔路國宅新村',
#    '大埔路慶安新村',
#    '大埔路有勝一村',
#    '大埔路有勝二村',
#    '大埔路有勝新村',
#    '大埔路東泰新村',
#    '大埔路錢龍新城',
#    '大埔路頂埔巷',
#    '大寮路',
#    '大寮路瑞芳工業區',
#    '尫子上天路',
#    '山尖路',
#    '岳王路',
#    '崙頂路',
#    '市下巷',
#    '平林路',
#    '建基新邨',
#    '建基路１段',
#    '建基路１段弘祥新村',
#    '建基路２段',
#    '後坑巷',
#    '新山路',
#    '新路尾路',
#    '明燈路１段',
#    '明燈路１段瑞柑新村',
#    '明燈路２段',
#    '明燈路３段',
#    '明里路',
#    '月眉路',
#    '東和路',
#    '東方瑞士',
#    '柴寮路',
#    '桀魚坑路',
#    '桀魚坑路瑞興新邨',
#    '桀魚坑路過港巷',
#    '楓子瀨路',
#    '民族街',
#    '民權街',
#    '民權街鐵路巷',
#    '民生街',
#    '永龍新邨',
#    '汽車路',
#    '洞頂路',
#    '海濱路',
#    '深澳路',
#    '滴水子路',
#    '濱二路',
#    '烏勢巷',
#    '烏塗堀路',
#    '瑞濱路',
#    '瑞濱路阿美家園',
#    '瑞竹路',
#    '瑞芳街',
#    '石埤巷',
#    '石壁坑路',
#    '石尾路',
#    '石崁巷',
#    '祈堂路',
#    '竪崎路',
#    '籠山路',
#    '粗坑口路',
#    '草山路',
#    '蘭陽路',
#    '蛇子形路',
#    '街頂巷',
#    '輕便路',
#    '逢甲路',
#    '逢甲路裕民新城',
#    '連福新城',
#    '達樂花園',
#    '金光路',
#    '長仁路',
#    '靜安路４段',
#    '頂坪路',
#    '頂坪路瑞芳工業區',
#    '魚寮路',
#    '黃金大鎮',
#    '鼻頭路'],
#   '平溪區': ['一坑',
#    '三坑',
#    '中埔',
#    '中華街',
#    '乾坑',
#    '二坑',
#    '五分寮',
#    '公園街',
#    '六分',
#    '十分街',
#    '南山坪',
#    '坑頭',
#    '大厝',
#    '大湖',
#    '嶺腳寮',
#    '平溪街',
#    '幼坑',
#    '新寮',
#    '月桃寮',
#    '望古坑',
#    '東勢格',
#    '柴橋坑',
#    '火燒寮',
#    '灰窯',
#    '瓜寮坑',
#    '田子',
#    '番子坑',
#    '白石腳',
#    '石底街',
#    '石灼坑',
#    '石硿子',
#    '石碣後',
#    '石筍尖',
#    '竿蓁坑',
#    '竿蓁林',
#    '粗坑',
#    '羗子坑',
#    '菁桐街',
#    '薯榔寮',
#    '雙菁路',
#    '靜安路２段',
#    '靜安路３段',
#    '頂寮子'],
#   '雙溪區': ['丁子蘭坑',
#    '三叉坑',
#    '三港',
#    '三貂里頂坑',
#    '中坑',
#    '中山路',
#    '中正路',
#    '中華路',
#    '五分',
#    '光復街',
#    '內厝',
#    '內平林',
#    '內挖路',
#    '內柑腳',
#    '八股',
#    '公泰山',
#    '公舘',
#    '勝利街',
#    '十三層',
#    '南陽',
#    '双澳',
#    '后番子坑',
#    '和平街',
#    '四分子',
#    '土地公山',
#    '土地公後',
#    '坤溪',
#    '外平林',
#    '外平林康福家園',
#    '外柑脚',
#    '大同街',
#    '大埤',
#    '大平',
#    '大瀨',
#    '太平路',
#    '定福',
#    '小坑',
#    '尫子崙坑',
#    '崩山坑',
#    '後寮子',
#    '政光',
#    '料角坑',
#    '新基北街',
#    '新基南街',
#    '新基東街',
#    '新基西街',
#    '新寮子',
#    '新店',
#    '朝陽街',
#    '東榮街',
#    '柑腳',
#    '柑腳下坑',
#    '梅竹蹊',
#    '泰和街',
#    '泰昌街',
#    '溪尾寮',
#    '灣潭',
#    '烏山',
#    '燦光寮',
#    '牡丹',
#    '牡丹里下坑',
#    '田寮',
#    '盤山坑',
#    '石壁坑',
#    '石笋',
#    '竹寮坑',
#    '竹林路',
#    '竹篙山',
#    '紙坑',
#    '聖南',
#    '聖右',
#    '自強路',
#    '警政街',
#    '赤皮崙',
#    '過溪',
#    '遠景',
#    '金山',
#    '長安街',
#    '長源里下坑',
#    '青雲',
#    '頂坪',
#    '魚杭',
#    '魚行里頂坑'],
#   '貢寮區': ['下双溪街',
#    '丹裡街',
#    '仁和路',
#    '仁愛路',
#    '仁義街',
#    '保健街',
#    '內寮街',
#    '內隆林街',
#    '北勢坑街',
#    '南勢坑街',
#    '和美街',
#    '土地公嶺街',
#    '外隆林街',
#    '大澳街',
#    '學苑街',
#    '尖山脚街',
#    '嵩陽街',
#    '巫里岸街',
#    '延平街',
#    '復興街',
#    '德心街',
#    '惠隆街',
#    '文秀坑街',
#    '新港街',
#    '朝陽街',
#    '東興街',
#    '枋脚街',
#    '桂安街',
#    '水返港街',
#    '泮宮路',
#    '田寮洋街',
#    '石壁坑街',
#    '研海街',
#    '福興街',
#    '福連街',
#    '福隆街',
#    '美灧山街',
#    '興隆街',
#    '荖寮街',
#    '蓬萊街',
#    '虎子山街',
#    '裕隆街',
#    '貢寮街',
#    '遠望坑街',
#    '長泰路',
#    '長潭街',
#    '雞母嶺街',
#    '香蘭街',
#    '馬崗街',
#    '龍洞街',
#    '龍門街',
#    '龜壽谷街'],
#   '新店區': ['三民路',
#    '下石厝路',
#    '中央一街',
#    '中央七街',
#    '中央三街',
#    '中央二街',
#    '中央五街',
#    '中央八街',
#    '中央六街',
#    '中央四街',
#    '中央路',
#    '中正路',
#    '中正路四維巷',
#    '中生路',
#    '中興路１段',
#    '中興路２段',
#    '中興路３段',
#    '中華路',
#    '二十張路',
#    '五峯路',
#    '僑仁路',
#    '僑信路',
#    '僑愛一路',
#    '僑愛七路',
#    '僑愛三路',
#    '僑愛九路',
#    '僑愛二路',
#    '僑愛五路',
#    '僑愛六路',
#    '僑愛四路',
#    '僑義路',
#    '光明街',
#    '光華街',
#    '力行路',
#    '北宜路１段',
#    '北宜路２段',
#    '北宜路３段',
#    '北新路１段',
#    '北新路２段',
#    '北新路３段',
#    '博愛街',
#    '合作路',
#    '吉安街',
#    '吉祥街',
#    '和成街',
#    '國校路',
#    '大同街',
#    '大學街',
#    '大新街',
#    '大榮路',
#    '大豐路',
#    '太平路',
#    '如意街',
#    '安一路１段',
#    '安一路２段',
#    '安光路',
#    '安利街',
#    '安和路１段',
#    '安和路２段',
#    '安和路３段',
#    '安平路',
#    '安康路１段',
#    '安康路２段',
#    '安康路３段',
#    '安德街',
#    '安忠路',
#    '安忠路振華巷',
#    '安成街',
#    '安捷路',
#    '安業街',
#    '安樂街',
#    '安民街',
#    '安泰路',
#    '安祥路',
#    '安興路',
#    '安華路',
#    '安豐路',
#    '富貴街',
#    '寶中路',
#    '寶元路１段',
#    '寶元路２段',
#    '寶安街',
#    '寶宏路',
#    '寶強路',
#    '寶慶街',
#    '寶橋路',
#    '寶興路',
#    '寶高路',
#    '小坑一路',
#    '小坑三路',
#    '小坑二路',
#    '屈尺路',
#    '屈尺路柏園巷',
#    '平廣路１段',
#    '平廣路２段',
#    '平等街',
#    '康雅崙路',
#    '廣興路',
#    '廣興路松碧巷',
#    '建國路',
#    '建安街',
#    '建業路',
#    '建興街',
#    '復興路',
#    '德正街',
#    '成功路',
#    '文中路',
#    '文化路',
#    '新和街',
#    '新坡一街',
#    '新店後街',
#    '新店路',
#    '新明街',
#    '新潭路１段',
#    '新潭路２段',
#    '新潭路３段',
#    '新烏路１段',
#    '新烏路２段',
#    '新烏路３段',
#    '新烏路３段寶島巷',
#    '新生街',
#    '新祥街',
#    '明山路',
#    '明德路',
#    '松林路',
#    '柴埕路',
#    '桂山路',
#    '桃李一路',
#    '桃李二路',
#    '梅崗一路',
#    '梅崗三路',
#    '梅花一路',
#    '橘園一路',
#    '檳榔路',
#    '櫻花街',
#    '民族路',
#    '民權路',
#    '民生路',
#    '永安街',
#    '永平街',
#    '永新街',
#    '永業路',
#    '永福路',
#    '永興路',
#    '永華街',
#    '涵碧路',
#    '湖子內路',
#    '湖興路',
#    '溪園路',
#    '溪洲路',
#    '灣潭路',
#    '玉山路',
#    '玫瑰路',
#    '環河路',
#    '環湖路',
#    '百忍街',
#    '百齡一路',
#    '百齡二路',
#    '直潭一街',
#    '直潭七街',
#    '直潭三街',
#    '直潭九街',
#    '直潭二街',
#    '直潭五街',
#    '直潭八街',
#    '直潭六街',
#    '直潭十街',
#    '直潭四街',
#    '直潭路',
#    '碧安街',
#    '碧潭路',
#    '祥和路',
#    '福園街',
#    '禾和一街',
#    '禾豐一路',
#    '禾豐七路',
#    '禾豐三路',
#    '禾豐九路',
#    '禾豐二路',
#    '禾豐五路',
#    '禾豐六路',
#    '禾豐十一路',
#    '秀山路',
#    '秀岡三街',
#    '秀岡二街',
#    '秀岡五街',
#    '秀岡六街１段',
#    '秀岡六街２段',
#    '秀岡六街３段',
#    '秀峯路',
#    '秀水路',
#    '竹林路',
#    '精忠路',
#    '翠峯路',
#    '能仁街',
#    '自強路',
#    '自由街',
#    '自立街',
#    '花園一路１段',
#    '花園一路２段',
#    '花園一路３段',
#    '花園一路４段',
#    '花園七路',
#    '花園七路１段',
#    '花園二路１段',
#    '花園二路２段',
#    '花園二路３段',
#    '花園五路１段',
#    '花園五路２段',
#    '花園六路',
#    '花園六路２段',
#    '花園六路３段',
#    '花園十二路',
#    '花園十路１段',
#    '花園十路２段',
#    '莒光路',
#    '華中街',
#    '華城一路',
#    '華城三路',
#    '華城二路',
#    '華城六街',
#    '華城路',
#    '華潭街',
#    '華興街',
#    '薏仁坑路',
#    '薏仁坑路自強巷',
#    '蘭苑一路',
#    '行政街',
#    '裕合街',
#    '車子路',
#    '達觀路',
#    '郵政路',
#    '金興路',
#    '金龍路',
#    '銀河路',
#    '錦秀路',
#    '長峯路',
#    '長春路',
#    '長興路',
#    '雙城路',
#    '雙峯路',
#    '青山路',
#    '青峯路',
#    '頂城一街',
#    '頂城三街',
#    '頂城二街',
#    '頂城五街',
#    '頂城六街',
#    '頂石厝路',
#    '順安街',
#    '黎明路'],
#   '坪林區': ['上坑子口',
#    '下坑子口',
#    '中心崙',
#    '九芎坑',
#    '九芎林',
#    '九芎根',
#    '乾溪',
#    '仁里坂',
#    '刣牛寮',
#    '北宜路７段',
#    '北宜路８段',
#    '北宜路９段',
#    '厚德岡坑',
#    '國中路',
#    '坪林',
#    '坪碇路',
#    '坪雙路１段',
#    '坪雙路２段',
#    '坪雙路３段',
#    '大粗坑',
#    '大舌湖',
#    '小粗坑',
#    '尖山湖',
#    '崩山坑',
#    '嶺腳坑',
#    '幼瀨',
#    '東坑',
#    '枋山坑',
#    '柑腳坑',
#    '桶盤嶼',
#    '楣子寮',
#    '樟空子',
#    '樹梅嶺',
#    '水柳腳',
#    '水聳淒坑',
#    '灣潭',
#    '烏窟子',
#    '石空子',
#    '石𥕢',
#    '碧湖',
#    '磨壁潭',
#    '竹子易',
#    '粗石斛',
#    '粗窟',
#    '苦苓腳',
#    '藤寮坑',
#    '虎寮潭',
#    '豹子厨',
#    '金瓜寮',
#    '闊瀨',
#    '鶯子瀨',
#    '鷺鶿岫',
#    '黃舉皮寮',
#    '𩻸魚堀'],
#   '烏來區': ['信福路',
#    '卡拉模基',
#    '啦卡路',
#    '堰堤',
#    '大羅蘭',
#    '天仁',
#    '娃娃谷',
#    '屯鹿',
#    '忠治',
#    '成功',
#    '新烏路４段',
#    '新烏路５段',
#    '李茂岸',
#    '桶後',
#    '溫泉街',
#    '瀑布',
#    '烏來街',
#    '環山路',
#    '紅河',
#    '西羅岸路',
#    '野要街',
#    '金堰',
#    '阿玉路',
#    '馬岸'],
#   '永和區': ['中和路',
#    '中山路１段',
#    '中正路',
#    '中興街',
#    '仁愛路',
#    '保安路',
#    '保平路',
#    '保慶街',
#    '保生路',
#    '保福路１段',
#    '保福路２段',
#    '保福路３段',
#    '保順路',
#    '信義路',
#    '光復街',
#    '勵行街',
#    '博愛街',
#    '厚德街',
#    '和平街',
#    '四維街',
#    '國中路',
#    '國光路',
#    '大新街',
#    '安樂路',
#    '安樂路一九八巷安和一弄',
#    '安樂路一九八巷安和二弄',
#    '得和路',
#    '復興街',
#    '忠孝街',
#    '成功路１段',
#    '成功路２段',
#    '文化路',
#    '新生路',
#    '智光街',
#    '林森路',
#    '民享街',
#    '民光街',
#    '民族街',
#    '民有街',
#    '民樂街',
#    '民權路',
#    '民治街',
#    '民生路',
#    '水源街',
#    '永亨路',
#    '永元路',
#    '永利路',
#    '永和路１段',
#    '永和路２段',
#    '永安街',
#    '永寧街',
#    '永平路',
#    '永貞路',
#    '環河東路１段',
#    '環河東路２段',
#    '環河東路３段',
#    '環河東路４段',
#    '環河西路１段',
#    '環河西路２段',
#    '福和路',
#    '秀安街',
#    '秀朗路１段',
#    '秀朗路２段',
#    '竹林路',
#    '自強街',
#    '自由街',
#    '警光街',
#    '警光街警光',
#    '警光街警光一巷',
#    '豫溪街',
#    '雙和街'],
#   '中和區': ['中原一街',
#    '中原三街',
#    '中原二街',
#    '中原五街',
#    '中原六街',
#    '中原東街',
#    '中原街',
#    '中原西街',
#    '中和路',
#    '中安街',
#    '中山路２段',
#    '中山路３段',
#    '中板路',
#    '中正路',
#    '中興街',
#    '仁愛街',
#    '保健路',
#    '保平路',
#    '信義街',
#    '光中路',
#    '光環路２段',
#    '光華街',
#    '勝利路',
#    '南山路',
#    '南工路',
#    '南華路',
#    '台新街',
#    '和城路１段',
#    '和平街',
#    '和平路',
#    '員山路',
#    '四維街',
#    '國光街',
#    '圓通路',
#    '壽德街',
#    '大仁街',
#    '大勇街',
#    '大智街',
#    '安和路',
#    '安平路',
#    '安樂路',
#    '安邦街',
#    '宜安路',
#    '工專路',
#    '廟美街',
#    '廣福路',
#    '建一路',
#    '建三路',
#    '建二路',
#    '建八路',
#    '建六路',
#    '建康路',
#    '復興路',
#    '德光路',
#    '忠孝街',
#    '成功路',
#    '捷運路',
#    '新民街',
#    '新生街',
#    '新福和街',
#    '新興街',
#    '明仁街',
#    '明禮街',
#    '明義街',
#    '景安路',
#    '景平路',
#    '景德街',
#    '景新街',
#    '更生街',
#    '板南路',
#    '枋寮街',
#    '橋和路',
#    '橋安街',
#    '民享街',
#    '民利街',
#    '民安街',
#    '民富街',
#    '民德路',
#    '民有街',
#    '民樂路',
#    '民治街',
#    '民生街',
#    '水源路',
#    '永和路',
#    '永貞路',
#    '泰和街',
#    '漢民路',
#    '環中路',
#    '環河西路３段',
#    '福祥路',
#    '福美路',
#    '秀峰街',
#    '秀朗路３段',
#    '立人街',
#    '立德街',
#    '立業路',
#    '立言街',
#    '自強路',
#    '自治街',
#    '自立路',
#    '興南路１段',
#    '興南路２段',
#    '興南路３段',
#    '莊敬路',
#    '莒光路',
#    '華安街',
#    '華新街',
#    '華福街',
#    '華順街',
#    '連勝街',
#    '連城路',
#    '錦和路'],
#   '土城區': ['三民路',
#    '中央路１段',
#    '中央路２段',
#    '中央路３段',
#    '中央路４段',
#    '中山路',
#    '中州路',
#    '中正路',
#    '中興路',
#    '中華路１段',
#    '中華路２段',
#    '亞洲路',
#    '仁愛路',
#    '信義路',
#    '光明街',
#    '勝利街',
#    '千歲路',
#    '南天母路',
#    '和城路２段',
#    '和平路',
#    '員安路',
#    '員林街',
#    '員福街',
#    '四川路',
#    '國際路',
#    '城林路',
#    '大同街',
#    '大安路',
#    '大暖坑',
#    '大暖路',
#    '學享街',
#    '學士路',
#    '學府路１段',
#    '學府路２段',
#    '學成路',
#    '學海街',
#    '峯廷街',
#    '廣明街',
#    '廣福街',
#    '廣興街',
#    '延吉街',
#    '延和路',
#    '延壽路',
#    '延安街',
#    '延峯街',
#    '延平街',
#    '復興街',
#    '德安街',
#    '德峯街',
#    '德興街',
#    '忠承路',
#    '忠義路',
#    '慶利街',
#    '慶和街',
#    '慶安街',
#    '慶樂街',
#    '慶祥街',
#    '成功街',
#    '承天路',
#    '擺接堡路',
#    '日和街',
#    '日新街',
#    '明峯街',
#    '明德路１段',
#    '明德路２段',
#    '樂利街',
#    '民安街',
#    '民族街',
#    '民權街',
#    '民生街',
#    '水源街',
#    '永和街',
#    '永安街',
#    '永寧路',
#    '永平街',
#    '永豐路',
#    '海山路',
#    '清水路',
#    '溪頭路',
#    '石門路',
#    '福仁街',
#    '福安街',
#    '福祥街',
#    '立仁街',
#    '立德路',
#    '立清街',
#    '立雲街',
#    '自強街',
#    '自由街',
#    '興城路',
#    '裕民路',
#    '裕生路',
#    '農豐街',
#    '金城路１段',
#    '金城路２段',
#    '金城路３段',
#    '金安街',
#    '青仁路',
#    '青和街',
#    '青山路',
#    '青福街',
#    '青隆街',
#    '青雲路',
#    '頂埔街',
#    '順風路',
#    '龍山一街',
#    '龍山二街',
#    '龍泉路'],
#   '三峽區': ['三十股路',
#    '三層坪路',
#    '三德路',
#    '三樹路',
#    '中園街',
#    '中埔',
#    '中山路',
#    '中正路１段',
#    '中正路２段',
#    '中正路３段',
#    '中興街',
#    '中華路',
#    '九份路',
#    '二鬮路',
#    '五寮',
#    '仁愛街',
#    '介壽路１段',
#    '介壽路２段',
#    '介壽路３段',
#    '佳福路',
#    '佳興路',
#    '信義街',
#    '光明路',
#    '和平街',
#    '嘉添',
#    '國光街',
#    '國學街',
#    '國慶路',
#    '國際一街',
#    '國際二街',
#    '圳頭',
#    '大仁路',
#    '大利路',
#    '大勇路',
#    '大同路',
#    '大埔路',
#    '大學路',
#    '大德路',
#    '大智路',
#    '大義路',
#    '大觀路',
#    '天德巷',
#    '學勤路',
#    '學府路',
#    '學成路',
#    '安坑',
#    '安溪路',
#    '建安',
#    '弘園街',
#    '弘道',
#    '復興路',
#    '忠孝街',
#    '愛國路',
#    '成福路',
#    '插角',
#    '文化路',
#    '新興街',
#    '有木',
#    '東眼',
#    '柑樹路',
#    '樟坑湖路',
#    '橫溪路',
#    '正義街',
#    '民族街',
#    '民權街',
#    '民生街',
#    '永安街',
#    '添福',
#    '清水街',
#    '溪北街',
#    '溪東路',
#    '牛角坑路',
#    '白雞',
#    '秀川街',
#    '竹安路',
#    '竹崙路',
#    '紫和路',
#    '紫微南路',
#    '紫微路',
#    '紫新路',
#    '茅埔',
#    '詩朗',
#    '金敏',
#    '長泰街',
#    '長福街',
#    '隆恩街',
#    '頭寮坑路',
#    '麻園',
#    '龍埔路'],
#   '樹林區': ['三俊街',
#    '三多路',
#    '三寶街',
#    '三德街',
#    '三福街',
#    '三興路',
#    '三龍街',
#    '中佳路',
#    '中和街',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中正路',
#    '中洲街',
#    '中興街',
#    '中華路',
#    '仁愛街',
#    '佳園路１段',
#    '佳園路２段',
#    '佳園路３段',
#    '俊保路',
#    '俊安街',
#    '俊德街',
#    '俊興街',
#    '俊英街',
#    '保安二街',
#    '保安街１段',
#    '保安街２段',
#    '保安街３段',
#    '保順街',
#    '信和街',
#    '信義街',
#    '備內街',
#    '備前街',
#    '光明街',
#    '光榮街',
#    '光武街',
#    '光興街',
#    '光華街',
#    '八德街',
#    '千歲街',
#    '博愛一街',
#    '博愛街',
#    '吉祥街',
#    '名園街',
#    '味王街',
#    '和平街',
#    '啓智街',
#    '四德街',
#    '四維路',
#    '國凱街',
#    '地政街',
#    '大同街',
#    '大安路',
#    '大慶街',
#    '大成路',
#    '大有路',
#    '大義路',
#    '大雅路',
#    '太元街',
#    '太平路',
#    '太順街',
#    '學勤路',
#    '學士路',
#    '學府路',
#    '學成路',
#    '學林路',
#    '寶園街',
#    '山佳街',
#    '工興街',
#    '後站街',
#    '復興路',
#    '德和街',
#    '忠信街',
#    '忠孝街',
#    '忠愛街',
#    '忠義街',
#    '文化街',
#    '文德街',
#    '新興街',
#    '日新街',
#    '東佳路',
#    '東和街',
#    '東大街',
#    '東榮街',
#    '東興街',
#    '東華街',
#    '東豐街',
#    '東陽街',
#    '東順街',
#    '板林路',
#    '柑園街１段',
#    '柑園街２段',
#    '桃子腳路',
#    '樹中二街',
#    '樹中街',
#    '樹人街',
#    '樹德街',
#    '樹新路',
#    '樹潭街',
#    '武林街',
#    '民和街',
#    '民權街',
#    '水源街',
#    '海明街',
#    '潭興街',
#    '環河路',
#    '環漢路５段',
#    '田尾街',
#    '福德街',
#    '福興街',
#    '福順街',
#    '立仁街',
#    '育德街',
#    '育英街',
#    '西圳街１段',
#    '西圳街２段',
#    '豐林街',
#    '鎮前街',
#    '長壽街',
#    '龍興街'],
#   '鶯歌區': ['三界公坑',
#    '三鶯路',
#    '中坑',
#    '中山路',
#    '中正一路',
#    '中正一路宛園巷',
#    '中正一路建德二巷',
#    '中正一路建德巷',
#    '中正一路碧龍巷',
#    '中正一路阿南巷',
#    '中正一路阿四巷',
#    '中正三路',
#    '中正三路曾厝巷',
#    '中正三路福德巷',
#    '中正三路許厝巷',
#    '中正三路邱厝巷',
#    '中正三路鄭厝巷',
#    '中正二路',
#    '中湖街',
#    '中湖街東學巷',
#    '中陽街',
#    '二橋新村',
#    '二橋街',
#    '二甲路',
#    '二甲路中心巷',
#    '二甲路佳美巷',
#    '二甲路光照巷',
#    '仁愛路',
#    '信義街',
#    '光復街',
#    '光明街',
#    '光照街',
#    '八德路',
#    '公園街',
#    '公有市場',
#    '南昌街',
#    '南雅路',
#    '博館路',
#    '和平街',
#    '國中街',
#    '國光街',
#    '國慶街',
#    '國華路',
#    '國際一路',
#    '國際二路',
#    '圳頭坑',
#    '大湖路',
#    '大湖路余厝巷',
#    '大湖路金包珠巷',
#    '宏德司法新村',
#    '宏德新村',
#    '尖山埔路',
#    '尖山埔路國小巷',
#    '尖山埔路２段',
#    '尖山路',
#    '尖山路卓厝巷',
#    '建國路',
#    '德昌二街',
#    '德昌街',
#    '忠孝街',
#    '成功街',
#    '文化路',
#    '文昌街',
#    '明圓街',
#    '明圓街一棟',
#    '明圓街七棟',
#    '明圓街三棟',
#    '明圓街九棟',
#    '明圓街二棟',
#    '明圓街五棟',
#    '明圓街八棟',
#    '明圓街六棟',
#    '明圓街四棟',
#    '晨曦街',
#    '晨曦街一棟',
#    '晨曦街三棟',
#    '晨曦街二棟',
#    '朝陽街',
#    '朝陽街五柳巷',
#    '朝陽街居易巷',
#    '朝陽街東坡巷',
#    '東湖路',
#    '樟普坑',
#    '欣欣街',
#    '欣欣街一棟',
#    '欣欣街七棟',
#    '欣欣街三棟',
#    '欣欣街九棟',
#    '欣欣街二棟',
#    '欣欣街五棟',
#    '欣欣街八棟',
#    '欣欣街六棟',
#    '欣欣街十一棟',
#    '欣欣街十棟',
#    '欣欣街四棟',
#    '正義新村',
#    '永利街',
#    '永吉街',
#    '永和二街',
#    '永和街',
#    '永安街',
#    '永昌街',
#    '永明街',
#    '永智街',
#    '永樂街',
#    '永福街',
#    '湖山路',
#    '環河路',
#    '福安街',
#    '福德一路',
#    '福德三街',
#    '福德二街',
#    '福德五街',
#    '福德四街',
#    '福昌街',
#    '福隆一街',
#    '福隆二街',
#    '育德街',
#    '育才街',
#    '育智路',
#    '育樂街',
#    '育英街',
#    '育賢街',
#    '莒光街',
#    '行政路',
#    '西湖街',
#    '西湖街曾厝巷',
#    '重慶街',
#    '重慶街南門商場',
#    '重慶街酒寮巷',
#    '陶瓷街',
#    '陽明街',
#    '館前路',
#    '香賓街',
#    '香賓街得月巷',
#    '高職南街',
#    '高職東街',
#    '高職西街',
#    '鳳一路',
#    '鳳七路',
#    '鳳三路',
#    '鳳五路',
#    '鳳吉一街',
#    '鳳吉三街',
#    '鳳吉二街',
#    '鳳吉五街',
#    '鳳吉四街',
#    '鳳福路',
#    '鳳鳴路',
#    '鶯桃路',
#    '鶯桃路永富巷',
#    '鶯桃路２段',
#    '鶯歌路',
#    '鶯華新村',
#    '黃厝街',
#    '龍一路',
#    '龍七路',
#    '龍三路',
#    '龍五路'],
#   '三重區': ['三信路',
#    '三光街',
#    '三和路１段',
#    '三和路２段',
#    '三和路３段',
#    '三和路４段',
#    '三寧街',
#    '三張街',
#    '三德街',
#    '三民街',
#    '三賢街',
#    '三陽路',
#    '下竹圍街',
#    '中央北路',
#    '中央南路',
#    '中寮街',
#    '中正北路',
#    '中正南路',
#    '中興北街',
#    '中興南街',
#    '中華路',
#    '五福街',
#    '五華街',
#    '五谷王北街',
#    '五谷王南街',
#    '仁信街',
#    '仁勇街',
#    '仁化商場',
#    '仁化街',
#    '仁厚街',
#    '仁和街',
#    '仁壽街',
#    '仁孝街',
#    '仁安街',
#    '仁忠街',
#    '仁愛街',
#    '仁慈街',
#    '仁政街',
#    '仁昌街',
#    '仁福街',
#    '仁美街',
#    '仁義街',
#    '仁興街',
#    '仁華街',
#    '仁賢街',
#    '介壽路',
#    '信義街',
#    '信義西街',
#    '信賢街',
#    '光復路１段',
#    '光復路２段',
#    '光明路',
#    '光興街',
#    '光華路',
#    '公園街',
#    '六張街',
#    '分子尾街',
#    '力行路１段',
#    '力行路２段',
#    '吉祥街',
#    '同安東街',
#    '同安街',
#    '名源街',
#    '和平街',
#    '國道路１段',
#    '國隆路',
#    '大仁街',
#    '大勇街',
#    '大同北路',
#    '大同南路',
#    '大智街',
#    '大有街',
#    '大榮街',
#    '如意街',
#    '安和路',
#    '安慶街',
#    '安樂街',
#    '安興街',
#    '富福街',
#    '富華街',
#    '富貴街',
#    '市前街',
#    '平安街',
#    '後埔街',
#    '後竹圍街',
#    '忠孝路１段',
#    '忠孝路２段',
#    '忠孝路３段',
#    '慈愛街',
#    '成功路',
#    '捷運路',
#    '文化北路',
#    '文化南路',
#    '新北大道１段',
#    '新北大道２段',
#    '新生街',
#    '新興路',
#    '昌隆街',
#    '明德街',
#    '明志街',
#    '朝陽街',
#    '正德街',
#    '正義北路',
#    '正義南路',
#    '民族街',
#    '民生東街',
#    '民生東街特',
#    '民生街',
#    '永安北路１段',
#    '永安北路２段',
#    '永德街',
#    '永春街',
#    '永福街',
#    '河邊北街',
#    '泉州街',
#    '洛陽街',
#    '溪尾街',
#    '環河北路１段',
#    '環河北路２段',
#    '環河北路３段',
#    '環河南路',
#    '環漢路１段',
#    '疏洪十六路',
#    '疏洪西路',
#    '碧華街',
#    '神農街',
#    '福和街',
#    '福德北路',
#    '福德南路',
#    '福華街',
#    '福裕街',
#    '福隆路',
#    '秀江街',
#    '竹圍仔街',
#    '簡仔畬街',
#    '聯華街',
#    '自強路１段',
#    '自強路２段',
#    '自強路３段',
#    '自強路４段',
#    '自強路５段',
#    '自由街',
#    '興德路',
#    '興華街',
#    '萬全街',
#    '萬壽街',
#    '貴陽街',
#    '車路頭街',
#    '通華街',
#    '進安街',
#    '過圳街',
#    '重光街',
#    '重化街',
#    '重安街',
#    '重新路１段',
#    '重新路２段',
#    '重新路３段',
#    '重新路４段',
#    '重新路５段',
#    '重陽路１段',
#    '重陽路２段',
#    '重陽路３段',
#    '重陽路４段',
#    '重陽路５段',
#    '金華街',
#    '錦通街',
#    '長元街',
#    '長元西街',
#    '長壽街',
#    '長壽西街',
#    '長安街',
#    '長春街',
#    '長榮路',
#    '長樂街',
#    '長生街',
#    '長興街',
#    '開元街',
#    '集仁街',
#    '集勇街',
#    '集成路',
#    '集智街',
#    '集美街',
#    '集英路',
#    '集賢路',
#    '雙園街',
#    '電信街',
#    '頂崁街',
#    '龍濱路',
#    '龍門路',
#    '龍門路特'],
#   '新莊區': ['三和路',
#    '三泰路',
#    '中信街',
#    '中原東路',
#    '中原路',
#    '中和街',
#    '中央路',
#    '中安街',
#    '中富街',
#    '中平路',
#    '中德路',
#    '中智街',
#    '中榮街',
#    '中正路',
#    '中正路力行巷',
#    '中正路新建巷',
#    '中正路新旺巷',
#    '中正路新生巷',
#    '中正路新雅巷',
#    '中正路育農巷',
#    '中泰街',
#    '中港一街',
#    '中港三街',
#    '中港二街',
#    '中港路',
#    '中港路中慶巷',
#    '中港路五守新村',
#    '中環路１段',
#    '中環路２段',
#    '中環路３段',
#    '中義街',
#    '中興街',
#    '中華路１段',
#    '中華路２段',
#    '中華路３段',
#    '中誠街',
#    '中貴路',
#    '丹鳳街',
#    '五工一路',
#    '五工三路',
#    '五工二路',
#    '五工五路',
#    '五工六路',
#    '五工路',
#    '五權一路',
#    '五權三路',
#    '五權二路',
#    '仁愛街',
#    '保安街１段',
#    '信華六街',
#    '光明路',
#    '光華街',
#    '八德街',
#    '公園一路',
#    '公園路',
#    '利濟街',
#    '化成路',
#    '化成路台貿二村',
#    '博愛路',
#    '和興街',
#    '四維路',
#    '壽山路',
#    '大安路',
#    '大觀街',
#    '天泉一街',
#    '天泉二街',
#    '天祥街',
#    '富國路',
#    '富貴路',
#    '幸福東路',
#    '幸福路',
#    '建中街',
#    '建國一路',
#    '建國二路',
#    '建安街',
#    '建福路',
#    '建興街',
#    '建豐街',
#    '後港一路',
#    '後港二路',
#    '復興路１段',
#    '復興路２段',
#    '復興路３段',
#    '德豐街',
#    '忠孝街',
#    '思明街',
#    '思源路',
#    '成功街',
#    '成德街',
#    '文藝路',
#    '新中街',
#    '新北大道２段',
#    '新北大道３段',
#    '新北大道４段',
#    '新北大道７段',
#    '新央街',
#    '新崑路',
#    '新樹路',
#    '新泰路',
#    '新知一路',
#    '新知三路',
#    '新知二路',
#    '新知五路',
#    '新知八路',
#    '新知六路',
#    '新知十路',
#    '新興街',
#    '新莊路',
#    '新豐街',
#    '昌仁路',
#    '昌和街',
#    '昌學街',
#    '昌平街',
#    '昌德街',
#    '昌明街',
#    '昌智路',
#    '昌盛街',
#    '昌義路',
#    '昌隆街',
#    '明中街',
#    '明志路',
#    '明智街',
#    '景德路',
#    '榮華路１段',
#    '榮華路２段',
#    '樹新路',
#    '武前街',
#    '民全街',
#    '民安東路',
#    '民安西路',
#    '民安路',
#    '民本街',
#    '民樂街',
#    '民生街',
#    '永安街',
#    '永寧街',
#    '永樂街',
#    '泰安街',
#    '泰豐街',
#    '泰順街',
#    '環漢路２段',
#    '環漢路３段',
#    '環漢路４段',
#    '瓊林北路',
#    '瓊林南路',
#    '瓊林路',
#    '瓊林路瓊英巷',
#    '瓊泰路',
#    '登龍街',
#    '碧江街',
#    '福前街',
#    '福壽街',
#    '福德一街',
#    '福德三街',
#    '福德二街',
#    '福慧路',
#    '福樂街',
#    '福海街',
#    '福營路',
#    '福美街',
#    '立信一街',
#    '立信三街',
#    '立信五街',
#    '義豐街',
#    '自信街',
#    '自強街',
#    '自治街',
#    '自由街',
#    '自立街',
#    '自重街',
#    '莊崑路',
#    '華興街',
#    '萬壽路１段',
#    '萬安街',
#    '裕民街',
#    '西盛街',
#    '豐年街',
#    '豐年街豐一巷',
#    '豐年街豐二巷',
#    '豐盛一街',
#    '豐盛二街',
#    '銘德街',
#    '長青街',
#    '雙鳳路',
#    '青山路１段',
#    '頭前路',
#    '頭成街',
#    '頭興街',
#    '鳳山街',
#    '麗水街',
#    '龍安路'],
#   '泰山區': ['中央路',
#    '中港南路',
#    '中港西路',
#    '中華街',
#    '仁德路',
#    '仁愛路',
#    '仁武街',
#    '仁義路',
#    '信義街',
#    '信華一街',
#    '信華三街',
#    '信華二街',
#    '信華五街',
#    '信華八街',
#    '信華六街',
#    '全興路',
#    '全興路全福巷',
#    '公園路',
#    '半山雅',
#    '南林路',
#    '南泰路',
#    '台貿三村',
#    '台麗街',
#    '同義街',
#    '吳厝窠',
#    '和平街',
#    '坡雅路',
#    '坡雅頭',
#    '壽山路',
#    '大科一路',
#    '大科路',
#    '工專路',
#    '干城三村',
#    '德安街',
#    '忠孝新村',
#    '忠孝街',
#    '憲訓路',
#    '應化街',
#    '應化街登山道',
#    '文化街',
#    '文程路',
#    '新五路１段',
#    '新北大道４段',
#    '新北大道５段',
#    '新北大道６段',
#    '新北大道７段',
#    '新民路',
#    '新生路',
#    '明志路１段',
#    '明志路２段',
#    '明志路３段',
#    '柯厝坑',
#    '楓樹街',
#    '楓江路',
#    '橫窠雅',
#    '民國街',
#    '民族街',
#    '民權街',
#    '民生路',
#    '泰山路',
#    '泰林路１段',
#    '泰林路２段',
#    '泰林路３段',
#    '漢口街',
#    '犁頭窠',
#    '磚雅厝',
#    '福德街',
#    '福泰街',
#    '福興一街',
#    '福興三街',
#    '福興二街',
#    '福興街',
#    '美寧街',
#    '致遠新村',
#    '莊泰路',
#    '莊田路',
#    '蘇厝坑',
#    '貴子路',
#    '貴陽街',
#    '貴鳳街',
#    '辭修路',
#    '錢厝坑',
#    '黎專路',
#    '黎明路'],
#   '林口區': ['三民路',
#    '下福',
#    '中北一街',
#    '中北三街',
#    '中北二街',
#    '中南一街',
#    '中原街',
#    '中山路',
#    '中正路',
#    '中湖',
#    '中興街',
#    '中華一路',
#    '中華路',
#    '井泉街',
#    '仁愛一路',
#    '仁愛二路',
#    '仁愛路１段',
#    '仁愛路２段',
#    '佳林路',
#    '信義路',
#    '八德路',
#    '公園路',
#    '南勢',
#    '南勢一街',
#    '南勢七街',
#    '南勢三街',
#    '南勢二街',
#    '南勢五街',
#    '南勢六街',
#    '南勢四街',
#    '南勢街',
#    '南福路',
#    '台電新村',
#    '吉林街',
#    '吉祥路',
#    '嘉溪雅坑',
#    '四維路',
#    '太平嶺',
#    '宏昌街',
#    '富貴路',
#    '寶斗厝坑',
#    '寶林路',
#    '工七路',
#    '工三路',
#    '工九路',
#    '工二區工七路',
#    '工二區工三路',
#    '工二區工九路',
#    '工二區工二路',
#    '工二區工五路',
#    '工二區工八路',
#    '工二區工六路',
#    '工二區工四路',
#    '工二工業區工七路',
#    '工二工業區工三路',
#    '工二工業區工九路',
#    '工二工業區工二路',
#    '工二工業區工五路',
#    '工二工業區工八路',
#    '工二工業區工六路',
#    '工二工業區工四路',
#    '工二路',
#    '工五路',
#    '工八路',
#    '工六路',
#    '工四路',
#    '干城二村',
#    '建國路',
#    '後坑',
#    '後湖',
#    '忠孝一路',
#    '忠孝三路',
#    '忠孝二路',
#    '忠孝路',
#    '忠福路',
#    '惠民新村',
#    '惠民街',
#    '文化一路１段',
#    '文化一路２段',
#    '文化三路１段',
#    '文化三路２段',
#    '文化二路１段',
#    '文化二路２段',
#    '文化北路１段',
#    '文化北路２段',
#    '文明街',
#    '文林一街',
#    '文林三街',
#    '文林二街',
#    '文林五街',
#    '文林六街',
#    '文林四街',
#    '文林街',
#    '新寮路',
#    '新生街',
#    '東明一街',
#    '東明三街',
#    '東明二街',
#    '東林街',
#    '東湖',
#    '東湖一街',
#    '東湖路',
#    '松柏路',
#    '林口路',
#    '民享路',
#    '民富街',
#    '民族路',
#    '民有街',
#    '民權路',
#    '民治路',
#    '民生路',
#    '汕頭',
#    '泰北路',
#    '湖子',
#    '源泉街',
#    '瑞樹坑',
#    '福林路',
#    '竹林一路',
#    '竹林路',
#    '粉寮',
#    '粉寮一街',
#    '粉寮路１段',
#    '粉寮路２段',
#    '粉寮醒吾新村',
#    '育林街',
#    '自強一街',
#    '自強七街',
#    '自強三街',
#    '自強九街',
#    '自強二街',
#    '自強五街',
#    '自強八街',
#    '自強六街',
#    '自強四街',
#    '興林一街',
#    '興林二街',
#    '興林路',
#    '菁埔',
#    '過崙街',
#    '隆林街',
#    '頂福',
#    '頭湖',
#    '麗園一街',
#    '麗園二街',
#    '麗園路'],
#   '蘆洲區': ['三民路',
#    '中原路',
#    '中央路',
#    '中山一路',
#    '中山二路',
#    '中正路',
#    '中興街',
#    '中華街',
#    '九芎街',
#    '仁愛街',
#    '保和街',
#    '信義路',
#    '光復路',
#    '光明路',
#    '光榮路',
#    '光華路',
#    '和平路',
#    '國道路２段',
#    '得勝街',
#    '復興路',
#    '忠孝路',
#    '成功路',
#    '正和街',
#    '民族路',
#    '民權路',
#    '民生街',
#    '民義街',
#    '水湳街',
#    '永安北路１段',
#    '永安北路２段',
#    '永安南路１段',
#    '永安南路２段',
#    '永平街',
#    '永康街',
#    '永樂街',
#    '環堤大道',
#    '重陽一街',
#    '重陽二街',
#    '重陽街',
#    '長安街',
#    '長榮路',
#    '長樂路',
#    '長興路',
#    '集賢路',
#    '鷺江街'],
#   '五股區': ['中直路',
#    '中直路崩山巷',
#    '中興路１段',
#    '中興路２段',
#    '中興路３段',
#    '中興路４段',
#    '五工一路',
#    '五工三路',
#    '五工二路',
#    '五工五路',
#    '五工六路',
#    '五工路',
#    '五權七路',
#    '五權三路',
#    '五權二路',
#    '五權五路',
#    '五權八路',
#    '五權六路',
#    '五權路',
#    '五福路',
#    '六合街',
#    '凌雲路１段',
#    '凌雲路２段',
#    '凌雲路３段',
#    '凌雲路３段田埔巷',
#    '四維路',
#    '國道路３段',
#    '壟鈎路',
#    '外寮路',
#    '天乙路',
#    '孝義路',
#    '工商路',
#    '御史路',
#    '御成路',
#    '成泰路１段',
#    '成泰路２段',
#    '成泰路３段',
#    '成泰路４段',
#    '成洲一路',
#    '成洲三路',
#    '成洲二路',
#    '成洲五路',
#    '成洲六路',
#    '新五路２段',
#    '新五路３段',
#    '新城一路',
#    '新城三路',
#    '新城二路',
#    '新城五路',
#    '新城八路',
#    '新城六路',
#    '明德路',
#    '更洲路',
#    '民義路１段',
#    '民義路２段',
#    '民義路３段',
#    '水碓一路',
#    '水碓七路',
#    '水碓三路',
#    '水碓九路',
#    '水碓二路',
#    '水碓五路',
#    '水碓六路',
#    '水碓路',
#    '洲子路',
#    '疏洪北路',
#    '疏洪東路',
#    '登林路',
#    '登林路貿商巷',
#    '自強路',
#    '芳洲一路',
#    '芳洲七路',
#    '芳洲三路',
#    '芳洲九路',
#    '芳洲二路',
#    '芳洲五路',
#    '芳洲八路',
#    '芳洲六路',
#    '芳洲路',
#    '蓬萊路',
#    '西雲路'],
#   '八里區': ['下罟子',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中華路１段',
#    '中華路２段',
#    '中華路３段',
#    '仁一街',
#    '仁三街',
#    '仁愛路',
#    '八里大道',
#    '十三行路',
#    '博物館路',
#    '厦竹圍',
#    '商港一路',
#    '商港七路',
#    '商港三路',
#    '商港九路',
#    '商港二路',
#    '商港五路',
#    '商港八路',
#    '商港六路',
#    '商港四路',
#    '商港路',
#    '四維街',
#    '坪子頂',
#    '埤頭一街',
#    '埤頭二街',
#    '大堀湖',
#    '大塘街',
#    '大崁一街',
#    '大崁三街',
#    '大崁二街',
#    '大崁腳',
#    '小坑',
#    '忠一街',
#    '忠七街',
#    '忠二街',
#    '忠五街',
#    '忠八街',
#    '忠六街',
#    '忠四街',
#    '忠孝路',
#    '挖子尾街',
#    '文化街',
#    '文心街',
#    '文昌一街',
#    '文昌七街',
#    '文昌三街',
#    '文昌二街',
#    '文昌五街',
#    '文昌六街',
#    '文昌路',
#    '松子腳',
#    '楓林坑',
#    '民享街',
#    '民有街',
#    '民治街',
#    '添丁街',
#    '渡船頭',
#    '渡船頭街',
#    '港區街',
#    '烏山頭',
#    '牛寮埔',
#    '狀元路',
#    '石壁腳',
#    '福德新村',
#    '米倉',
#    '義民街',
#    '舊城路',
#    '荖阡坑路',
#    '華富山',
#    '華峰一街',
#    '華峰三街',
#    '華峰二街',
#    '觀海大道',
#    '訊埔路',
#    '訊塘一路',
#    '訊塘二路',
#    '訊塘埔',
#    '訊塘路',
#    '賢一街',
#    '賢三街',
#    '賢二街',
#    '長坑口',
#    '長道坑',
#    '頂寮',
#    '頂寮一街',
#    '頂寮三街',
#    '頂寮二街',
#    '頂寮五街',
#    '頂罟一路',
#    '頂罟二路',
#    '龍形一街',
#    '龍形三街',
#    '龍形二街',
#    '龍形五街',
#    '龍米路１段',
#    '龍米路２段',
#    '龍米路３段'],
#   '淡水區': ['三塊厝',
#    '三民街',
#    '三空泉',
#    '三角埔',
#    '下圭柔山',
#    '下田寮',
#    '中山北路１段',
#    '中山北路２段',
#    '中山北路３段',
#    '中山路',
#    '中正東路',
#    '中正東路１段',
#    '中正東路２段',
#    '中正路',
#    '中正路１段',
#    '中正路２段',
#    '中洲子',
#    '仁愛街',
#    '八勢一街',
#    '八勢二街',
#    '八勢路',
#    '八勢路１段',
#    '八里堆',
#    '公埔子',
#    '公明街',
#    '六塊厝',
#    '前洲子',
#    '北勢子',
#    '北投子',
#    '北新路',
#    '北新路１段',
#    '北新路２段',
#    '北新路３段',
#    '南勢埔',
#    '南平',
#    '博愛街',
#    '原德路',
#    '口湖子',
#    '吳仔厝',
#    '商工路',
#    '坪頂路',
#    '埔子頂',
#    '埤島',
#    '大仁街',
#    '大信街',
#    '大勇街',
#    '大同路',
#    '大埤頭',
#    '大忠街',
#    '大智街',
#    '大溪',
#    '大牛稠',
#    '大竹圍',
#    '大義街',
#    '奎柔山路',
#    '學府路',
#    '安子內',
#    '小中寮',
#    '小坑子頭',
#    '小坪頂',
#    '山子邊',
#    '山子頂',
#    '崁頂',
#    '崁頂三路',
#    '崁頂五路',
#    '崙頂',
#    '平遠街',
#    '店子後',
#    '店子路',
#    '建設街',
#    '後坑子',
#    '後寮',
#    '後洲子',
#    '後洲路１段',
#    '忠愛街',
#    '文化路',
#    '新埔子',
#    '新市一路１段',
#    '新市一路２段',
#    '新市一路３段',
#    '新市三路',
#    '新市三路１段',
#    '新市三路２段',
#    '新市三路３段',
#    '新市二路１段',
#    '新市二路２段',
#    '新市二路３段',
#    '新市二路４段',
#    '新市五路１段',
#    '新市五路２段',
#    '新市五路３段',
#    '新市五路４段',
#    '新市四路',
#    '新春街',
#    '新民街',
#    '新民街１段',
#    '新生街',
#    '新興街',
#    '桂竹圍',
#    '桂花樹',
#    '椿子林',
#    '楓丹白露',
#    '楓樹湖',
#    '樟腦寮坪',
#    '樹林口',
#    '樹梅坑',
#    '民富街',
#    '民族路',
#    '民權一街',
#    '民權路',
#    '民生路',
#    '水尾子',
#    '水梘頭',
#    '水汴頭',
#    '水源街１段',
#    '水源街２段',
#    '水碓',
#    '水碓街',
#    '永興巷',
#    '沙崙路',
#    '沙崙路１段',
#    '沙崙路２段',
#    '泉州厝',
#    '淡海路',
#    '淡金路',
#    '淡金路１段',
#    '淡金路２段',
#    '淡金路３段',
#    '淡金路４段',
#    '淡金路５段',
#    '清水街',
#    '溪口',
#    '演戲埔腳',
#    '濱海路',
#    '濱海路１段',
#    '濱海路２段',
#    '濱海路３段',
#    '牛埔子',
#    '瓦磘坑',
#    '番子厝',
#    '番子田',
#    '番社前',
#    '白石腳',
#    '百六戞',
#    '相公山',
#    '真理街',
#    '石頭厝',
#    '石頭埔',
#    '破布子腳',
#    '破瓦厝子',
#    '碧湖',
#    '社厝坑',
#    '竹圍子',
#    '竹林路',
#    '竿蓁一街',
#    '竿蓁二街',
#    '糞箕湖',
#    '紅樹林路',
#    '義山路',
#    '義山路１段',
#    '義山路２段',
#    '自強路',
#    '自強路埔頂巷',
#    '自立路',
#    '興仁路',
#    '興福寮',
#    '英專路',
#    '行忠路',
#    '觀海路',
#    '車路腳',
#    '鄒厝崙',
#    '鄧公路',
#    '重建街',
#    '長興街',
#    '雲廣坑',
#    '頂田寮',
#    '頂田寮路',
#    '馬偕街',
#    '鼻頭街'],
#   '三芝區': ['三民街',
#    '中山路１段',
#    '中山路２段',
#    '中正路１段',
#    '中正路２段',
#    '中正路３段',
#    '中興街１段',
#    '中興街２段',
#    '二坪頂',
#    '五脚松',
#    '光仁街',
#    '光復街',
#    '光明街',
#    '光華街',
#    '光隆街',
#    '內柑宅',
#    '八連溪',
#    '八連溪頭',
#    '公正街',
#    '公正街３段',
#    '利民街',
#    '北勢子',
#    '北海路２段',
#    '南勢崗',
#    '古庄',
#    '四棧橋',
#    '土地公坑',
#    '土地公埔',
#    '埔尾',
#    '埔頭',
#    '埔頭坑',
#    '大坑',
#    '大水堀',
#    '大湖',
#    '大片頭',
#    '小坑子',
#    '山豬堀',
#    '店子',
#    '忠孝街',
#    '新庄子',
#    '晴光街',
#    '智成街',
#    '木屐寮',
#    '梀板頭',
#    '楓子林',
#    '楓林一街',
#    '楓林三街',
#    '楓林二街',
#    '楓林五街',
#    '楓林六街',
#    '楓林路',
#    '樂全街',
#    '橫山',
#    '櫻花山莊',
#    '民生街',
#    '海尾',
#    '海景一街',
#    '海景三街',
#    '海景二街',
#    '海景五街',
#    '海景四街',
#    '淡金路１段',
#    '淡金路２段',
#    '淺水灣',
#    '淺水灣街',
#    '田心子',
#    '番婆林',
#    '番子崙',
#    '番社后',
#    '石曹子坑',
#    '聽濤街',
#    '育英街',
#    '芝柏一街',
#    '芝柏三街',
#    '芝柏二街',
#    '芝柏五街',
#    '芝柏路',
#    '芝麻一街',
#    '芝麻三街',
#    '芝麻二街',
#    '芝麻五街',
#    '芝麻四街',
#    '茂興店',
#    '菜公坑',
#    '蕃社后',
#    '蘭陽街',
#    '觀海街',
#    '車埕',
#    '車新路',
#    '迎旭街',
#    '長勤街',
#    '長安街',
#    '長春街',
#    '陳厝坑',
#    '陽住坑',
#    '陽明路',
#    '龜子山'],
#   '石門區': ['七股',
#    '下員坑',
#    '中央路',
#    '中山路',
#    '九芎林',
#    '五爪崙',
#    '內石門',
#    '內阿里磅',
#    '八甲',
#    '公地',
#    '嘉祿街',
#    '坪林',
#    '大丘田',
#    '大溪墘',
#    '富貴角',
#    '小坑',
#    '尖子鹿',
#    '尖山湖',
#    '崁子脚',
#    '楓林',
#    '海園路',
#    '海灣新城',
#    '猪槽潭',
#    '白沙灣別墅',
#    '石崩山',
#    '石門新村',
#    '石門街',
#    '福安街',
#    '竹子湖',
#    '老崩山',
#    '老梅路',
#    '臨海別墅',
#    '茂林社區',
#    '草埔尾',
#    '金華新城',
#    '阿里磅',
#    '阿里荖',
#    '麟山鼻']},
#  '連江縣': {'南竿鄉': ['仁愛村',
#    '介壽村',
#    '四維村',
#    '復興村',
#    '津沙村',
#    '清水村',
#    '珠螺村',
#    '福沃村',
#    '馬祖村'],
#   '北竿鄉': ['后沃村', '坂里村', '塘岐村', '橋仔村', '白沙村', '芹壁村'],
#   '莒光鄉': ['大坪村', '田沃村', '福正村', '西坵村', '青帆村'],
#   '東引鄉': ['中柳村', '樂華村']},
#  '宜蘭縣': {'宜蘭市': ['一結路',
#    '七張路',
#    '三清路',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中山路３段中央商場',
#    '中山路５段',
#    '中興路',
#    '中華路',
#    '健康路１段',
#    '健康路２段',
#    '健康路３段',
#    '光復路',
#    '公園北路',
#    '公園路',
#    '凱旋路',
#    '力新路',
#    '力行街力行巷',
#    '力行路',
#    '北津路',
#    '南橋一路',
#    '南橋三路',
#    '南橋二路',
#    '南橋路',
#    '南津路',
#    '南興街',
#    '吉祥路',
#    '同慶街',
#    '同興街',
#    '和睦路',
#    '和睦路團管區巷',
#    '和睦路軍友巷',
#    '和睦路鐵路一巷',
#    '和睦路鐵路二巷',
#    '國榮路',
#    '城隍街',
#    '壯二路',
#    '大坡路１段',
#    '大坡路２段',
#    '大學路',
#    '大福路１段',
#    '大福路２段',
#    '女中路',
#    '女中路１段',
#    '女中路２段',
#    '女中路３段',
#    '宜中路',
#    '宜科路',
#    '宜興路１段',
#    '宜興路２段',
#    '宜興路３段',
#    '富農路',
#    '小東路',
#    '崇聖街',
#    '嵐峰路１段',
#    '嵐峰路２段',
#    '嵐峰路３段',
#    '幸福路',
#    '康樂路',
#    '延平一路',
#    '延平路',
#    '建業路',
#    '建蘭北路',
#    '建蘭南路',
#    '建軍路',
#    '建軍路凌雲新村',
#    '建軍路建國新村',
#    '建軍路蘭竹新村',
#    '弘志路',
#    '復興路',
#    '復興路１段',
#    '復興路２段',
#    '復興路３段',
#    '忠義路',
#    '惠深二路１段',
#    '慈安路',
#    '慈航一路',
#    '慈航三路',
#    '慈航二路',
#    '慈航路',
#    '慈雲路',
#    '慶和街',
#    '慶和街同興巷',
#    '慶和街慶和巷',
#    '成功路',
#    '擺厘路',
#    '文化路',
#    '文昌路',
#    '新民路',
#    '新民路大東巷',
#    '新生路',
#    '新興路',
#    '旋流路',
#    '昇平街',
#    '東園路',
#    '東後街',
#    '東後街東後巷',
#    '東津二路',
#    '東津路',
#    '東港路',
#    '東港路校舍巷',
#    '東港路福德巷',
#    '東港路１段',
#    '東港路２段',
#    '林森路',
#    '校舍一路',
#    '校舍二路',
#    '校舍路',
#    '梅洲一路',
#    '梅洲二路',
#    '樹人路',
#    '武暖路',
#    '武營街',
#    '民族路',
#    '民權新路',
#    '民權路１段',
#    '民權路２段',
#    '民權路３段',
#    '民生新街',
#    '民生街',
#    '水源路',
#    '永樂路',
#    '永金三路',
#    '河濱北路',
#    '河濱南路',
#    '泰山路',
#    '泰山路七結巷',
#    '泰山路寺後巷',
#    '泰山路復國巷',
#    '泰山路民族一巷',
#    '泰山路民族二巷',
#    '泰山路負郭二巷',
#    '津梅一路',
#    '津梅路',
#    '清華一路',
#    '清華二路',
#    '清華路',
#    '珍珠路',
#    '環市南路',
#    '環市東路１段',
#    '環市東路２段',
#    '環市東路３段',
#    '環河北路',
#    '環河東路',
#    '環河路',
#    '碧霞街',
#    '神農路１段',
#    '神農路２段',
#    '福德路',
#    '縣政一街',
#    '縣政七街',
#    '縣政三街',
#    '縣政九街',
#    '縣政二街',
#    '縣政五街',
#    '縣政八街',
#    '縣政六街',
#    '縣政北路',
#    '縣政十二街',
#    '縣政十街',
#    '縣政南路',
#    '縣政西路',
#    '縣民大道２段',
#    '聖後街',
#    '育才路',
#    '自強新路',
#    '自強路',
#    '舊城北路',
#    '舊城南路',
#    '舊城南路縣府一巷',
#    '舊城南路縣府二巷',
#    '舊城南路縣府四巷',
#    '舊城東路',
#    '舊城西路',
#    '舊城西路光大巷',
#    '茭白一路',
#    '茭白三路',
#    '茭白二路',
#    '茭白路',
#    '西安街',
#    '西後街',
#    '西門路',
#    '負郭路',
#    '賢好路',
#    '軍民路',
#    '農權路',
#    '農權路２段',
#    '農權路３段',
#    '進士路',
#    '金六結路',
#    '金同春路',
#    '金山東路',
#    '金泰路',
#    '鎮平一路',
#    '鎮平二路',
#    '鎮平路',
#    '長春路',
#    '開興路',
#    '陽明一路',
#    '陽明三路',
#    '陽明二路',
#    '陽明六路',
#    '陽明路',
#    '雪峰一路',
#    '雪峰三路',
#    '雪峰二路',
#    '雪峰路',
#    '雪隧路',
#    '黎明一路',
#    '黎明三路',
#    '黎明三路１段',
#    '黎明二路',
#    '黎明路'],
#   '壯圍鄉': ['中央路１段',
#    '中央路２段',
#    '中央路３段',
#    '中興一路',
# ...
#    '介林六街',
#    '介林四街',
#    '介禮街',
#    '介義街',
#    '佐倉街',
#    '信義街',
#    '光復街',
#    '光華街',
#    '公園路',
#    '公正新村',
#    '公正街',
#    '勵志新村',
#    '化道路',
#    '北濱街',
#    '北興路',
#    '南京街',
#    '南濱路',
#    '博愛街',
#    '司法新村',
#    '吉林路',
#    '和平路',
#    '商校街',
#    '國富',
#    '國富一街',
#    '國富七街',
#    '國富三街',
#    '國富九街',
#    '國富二十一街',
#    '國富二十七街',
#    '國富二十三街',
#    '國富二十二街',
#    '國富二十五街',
#    '國富二十八街',
#    '國富二十六街',
#    '國富二十四街',
#    '國富二十街',
#    '國富二街',
#    '國富五街',
#    '國富八街',
#    '國富六街',
#    '國富十一街',
#    '國富十七街',
#    '國富十三街',
#    '國富十九街',
#    '國富十二街',
#    '國富十五街',
#    '國富十八街',
#    '國富十六街',
#    '國富十四街',
#    '國富十街',
#    '國民',
#    '國民一街',
#    '國民七街',
#    '國民三街',
#    '國民九街',
#    '國民二街',
#    '國民五街',
#    '國民八街',
#    '國民六街',
#    '國民十一街',
#    '國民十二街',
#    '國民十街',
#    '國民四街',
#    '國盛一街',
#    '國盛七街',
#    '國盛三街',
#    '國盛二街',
#    '國盛五街',
#    '國盛八街',
#    '國盛六街',
#    '國盛四街',
#    '國福街',
#    '國聯一路',
#    '國聯三路',
#    '國聯二路',
#    '國聯五路',
#    '國聯四路',
#    '國興一街',
#    '國興三街',
#    '國興二街',
#    '國興五街',
#    '國興六街',
#    '國興四街',
#    '國風',
#    '國風街',
#    '基泰商場',
#    '大同街',
#    '大廈街',
#    '大禹街',
#    '富吉路',
#    '富國路',
#    '富安路',
#    '富強路',
#    '富祥街',
#    '富裕一街',
#    '富裕七街',
#    '富裕三街',
#    '富裕九街',
#    '富裕二街',
#    '富裕五街',
#    '富裕八街',
#    '富裕六街',
#    '富裕十一街',
#    '富裕十七街',
#    '富裕十三街',
#    '富裕十二街',
#    '富裕十五街',
#    '富裕十六街',
#    '富裕十四街',
#    '富裕十街',
#    '富陽路',
#    '尚志路',
#    '府前路',
#    '府後路',
#    '康樂街',
#    '廣東街',
#    '延平街',
#    '建中街',
#    '建信街',
#    '建和街',
#    '建國路',
#    '建國路２段',
#    '建安街',
#    '建德街',
#    '建成街',
#    '建昌路',
#    '建林街',
#    '建興街',
#    '建華路',
#    '影劇四村',
#    '復興新村',
#    '復興街',
#    '德安一街',
#    '德安三街',
#    '德安二街',
#    '德安五街',
#    '德安六街',
#    '德安四街',
#    '德興',
#    '忠孝街',
#    '忠義一街',
#    '忠義三街',
#    '忠義二街',
#    '忠義四街',
#    '成功街',
#    '文光街',
#    '文復路',
#    '文苑路',
#    '新港街',
#    '新興路',
#    '日新崗',
#    '明心街',
#    '明智街',
#    '明禮路',
#    '明義街',
#    '有恆街',
#    '東興一街',
#    '東興三街',
#    '東興二街',
#    '東興街',
#    '東興路',
#    '松園街',
#    '林園',
#    '林園一街',
#    '林園三街',
#    '林園二街',
#    '林政街',
#    '林森路',
#    '林榮街',
#    '榮正街',
#    '樹人街',
#    '正義街',
#    '民享一街',
#    '民享七街',
#    '民享三街',
#    '民享九街',
#    '民享二街',
#    '民享五街',
#    '民享八街',
#    '民享六街',
#    '民享十街',
#    '民享四街',
#    '民光',
#    '民國路',
#    '民孝街',
#    '民德一街',
#    '民德三街',
#    '民德二街',
#    '民德四街',
#    '民族路',
#    '民樂一街',
#    '民樂三街',
#    '民樂二街',
#    '民權一街',
#    '民權七街',
#    '民權三街',
#    '民權九街',
#    '民權二街',
#    '民權五街',
#    '民權八街',
#    '民權六街',
#    '民權四街',
#    '民權路',
#    '民生路',
#    '水源街',
#    '永安街',
#    '永興路',
#    '沙基拉雅街',
#    '海岸路',
#    '海濱街',
#    '港口路',
#    '港濱',
#    '濟慈路',
#    '球崙一路',
#    '球崙二路',
#    '球崙街',
#    '瑞美路',
#    '睦和街',
#    '石壁街',
#    '福光街',
#    '福建一街',
#    '福建三街',
#    '福建二街',
#    '福建街',
#    '福德一街',
#    '福德三街',
#    '福德二街',
#    '福德四街',
#    '福源街',
#    '節約街',
#    '精忠七村',
#    '精美路',
#    '綜合市場',
#    '縣府新村',
#    '美崙山新村',
#    '美崙市場',
#    '美工七街',
#    '美工三街',
#    '美工九街',
#    '美工五街',
#    '美工八街',
#    '美工六街',
#    '美工四街',
#    '美工路',
#    '育樂新村',
#    '自強街',
#    '自由街',
#    '花商新村',
#    '花崗街',
#    '花蓮街',
#    '莊敬路',
#    '菁華街',
#    '華國街',
#    '華安街',
#    '華廈街',
#    '華德街',
#    '華東',
#    '華民街',
#    '華泰街',
#    '華興街',
#    '華西',
#    '裕民路',
#    '裕祥路',
#    '警光一村',
#    '警光新村',
#    '豐村',
#    '軒轅路',
#    '進豐街',
#    '達固湖灣大路',
#    '重慶路',
#    '鎮國街',
#    '長安街',
#    '長春街',
#    '開發新村',
#    '開興路',
#    '順興路'],
#   '新城鄉': ['七星街',
#    '中山路',
#    '中正路',
#    '中正路凌雲巷',
#    '中正路懷德巷',
#    '中興路',
#    '仁愛路',
#    '仁義街',
#    '佳林',
#    '佳祥巷',
#    '佳運巷',
#    '信義路',
#    '光復路',
#    '加灣',
#    '助人街',
#    '北三棧',
#    '北埔路',
#    '南三棧',
#    '博愛路',
#    '古井街',
#    '嘉北一街',
#    '嘉北二街',
#    '嘉南一街',
#    '嘉南路',
#    '嘉新',
#    '嘉新路',
#    '嘉里一街',
#    '嘉里一路',
#    '嘉里三街',
#    '嘉里三路',
#    '嘉里二街',
#    '嘉里二路',
#    '嘉里四路',
#    '嘉里路',
#    '嘉里路機場',
#    '大同街',
#    '大安街',
#    '大德街',
#    '大方街',
#    '大有街',
#    '大漢街',
#    '大華街',
#    '大行街',
#    '大賢街',
#    '安樂街',
#    '山廣',
#    '康平街',
#    '康樂',
#    '康樂一街',
#    '康樂三街',
#    '康樂路',
#    '康泰街',
#    '廣安一街',
#    '廣安三街',
#    '廣安二街',
#    '建國街',
#    '復興路',
#    '德莊街',
#    '文化路',
#    '新城路',
#    '新興一街',
#    '新興一路',
#    '新興三路',
#    '新興二街',
#    '新興二路',
#    '新興六街',
#    '新興路',
#    '明潭街',
#    '樹人街',
#    '樹德街',
#    '樹林街',
#    '機場巷',
#    '民享街',
#    '民勤街',
#    '民族路',
#    '民有一街',
#    '民有三街',
#    '民有二街',
#    '民有五街',
#    '民有四街',
#    '民有街',
#    '民權街',
#    '民治街',
#    '民生路',
#    '海岸路',
#    '漁場街',
#    '福德路',
#    '立業街',
#    '精舍街',
#    '紫園一巷',
#    '紫園三巷',
#    '紫園二巷',
#    '紫園巷',
#    '自信街',
#    '自助街',
#    '自強街',
#    '自然街',
#    '自立街',
#    '致遠街',
#    '花師街',
#    '草林',
#    '華富街',
#    '華德街',
#    '華興街',
#    '華陽街',
#    '鄉根一巷',
#    '鄉根二巷',
#    '順興街'],
#   '秀林鄉': ['三棧',
#    '五橋',
#    '佳民',
#    '克來寶',
#    '克尼布東路',
#    '加灣',
#    '可樂',
#    '和中',
#    '和仁',
#    '和工二路',
#    '和工五路',
#    '和工四路',
#    '和平',
#    '大山',
#    '大清水',
#    '大禹嶺',
#    '天祥',
#    '富世',
#    '崇德',
#    '慈恩',
#    '文蘭',
#    '新白揚',
#    '梅園',
#    '榕樹',
#    '民享',
#    '民有',
#    '民樂',
#    '民治',
#    '水源',
#    '洛韶',
#    '海濱',
#    '清水',
#    '碧綠',
#    '秀林',
#    '竹村',
#    '米亞丸',
#    '華綠溪',
#    '蓮池',
#    '西寶',
#    '重光',
#    '金嵐',
#    '銅門',
#    '關原',
#    '龍澗'],
#   '吉安鄉': ['中原路１段',
#    '中央路１段',
#    '中央路２段',
#    '中央路３段',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中山路４段',
#    '中正路１段',
#    '中正路２段',
#    '中興路',
#    '中華路',
#    '中華路２段',
#    '仁光',
#    '仁愛新村',
#    '仁里一街',
#    '仁里七街',
#    '仁里三街',
#    '仁里九街',
#    '仁里二街',
#    '仁里五街',
#    '仁里八街',
#    '仁里六街',
#    '仁里十三街',
#    '仁里十二街',
#    '仁里十四街',
#    '仁里四街',
#    '光城路',
#    '光華一街',
#    '光華七街',
#    '光華三街',
#    '光華九街',
#    '光華二街',
#    '光華五街',
#    '光華八街',
#    '光華六街',
#    '光華十街',
#    '光華四街',
#    '光華街',
#    '全民街',
#    '公園街',
#    '勝安一街',
#    '勝安三街',
#    '勝安二街',
#    '勝安四街',
#    '北安街',
#    '北昌一街',
#    '北昌三街',
#    '北昌二街',
#    '北昌五街',
#    '北昌四街',
#    '南埔一街',
#    '南埔七街',
#    '南埔九街',
#    '南埔二街',
#    '南埔五街',
#    '南埔八街',
#    '南埔十一街',
#    '南埔十三街',
#    '南埔十二街',
#    '南埔十五街',
#    '南埔十六街',
#    '南埔十街',
#    '南埔四街',
#    '南埔新村',
#    '南山一街',
#    '南山三街',
#    '南山二街',
#    '南山五街',
#    '南山六街',
#    '南山四街',
#    '南昌',
#    '南昌北路',
#    '南昌路',
#    '南海一街',
#    '南海七街',
#    '南海三街',
#    '南海九街',
#    '南海二街',
#    '南海五街',
#    '南海八街',
#    '南海六街',
#    '南海十一街',
#    '南海十三街',
#    '南海十二街',
#    '南海十街',
#    '南海四街',
#    '南濱路１段',
#    '南華一街',
#    '南華七街',
#    '南華三街',
#    '南華二街',
#    '南華五街',
#    '南華八街',
#    '南華六街',
#    '南華四街',
#    '博愛街',
#    '吉城一街',
#    '吉城二街',
#    '吉太街',
#    '吉安路１段',
#    '吉安路２段',
#    '吉安路３段',
#    '吉安路５段',
#    '吉安路６段',
#    '吉慶街',
#    '吉昌一街',
#    '吉昌三街',
#    '吉昌二街',
#    '吉祥一街',
#    '吉祥七街',
#    '吉祥三街',
#    '吉祥九街',
#    '吉祥二街',
#    '吉祥五街',
#    '吉祥八街',
#    '吉祥六街',
#    '吉祥十二街',
#    '吉祥四街',
#    '吉興一街',
#    '吉興三街',
#    '吉興二街',
#    '吉興五街',
#    '吉興六街',
#    '吉興四街',
#    '吉興路１段',
#    '吉興路２段',
#    '吉興路３段',
#    '吉豐路１段',
#    '吉豐路２段',
#    '吉豐路３段',
#    '吉豐路５段',
#    '名人',
#    '和平路１段',
#    '和興街',
#    '國富',
#    '國興街',
#    '城中一街',
#    '城中四街',
#    '壽昌街',
#    '太昌山邊',
#    '太昌路',
#    '宜昌一街',
#    '宜昌七街',
#    '宜昌三街',
#    '宜昌二街',
#    '宜昌五街',
#    '宜昌六街',
#    '宜昌四街',
#    '富祥街',
#    '山上',
#    '山下一街',
#    '山下三街',
#    '山下二街',
#    '山下五街',
#    '山下四街',
#    '山下路',
#    '山腳',
#    '山腳一街',
#    '山邊',
#    '干城',
#    '干城一街',
#    '干城三街',
#    '干城二街',
#    '廣興一街',
#    '廣豐一街',
#    '廣豐三街',
#    '廣豐二街',
#    '廣豐路',
#    '廣賢一街',
#    '廣賢三街',
#    '廣賢二街',
#    '廣賢五街',
#    '廣賢路１段',
#    '廣賢路２段',
#    '建國路',
#    '建國路１段',
#    '建國路２段',
#    '建昌路',
#    '復興一街',
#    '復興三街',
#    '復興二街',
#    '復興四街',
#    '慈惠一街',
#    '慈惠三街',
#    '慈惠二街',
#    '慈惠五街',
#    '慈惠六街',
#    '慈惠四街',
#    '慈雲山',
#    '慈雲路',
#    '慶北一街',
#    '慶北三街',
#    '慶北二街',
#    '慶南一街',
#    '慶南三街',
#    '慶南二街',
#    '慶南四街',
#    '慶豐一街',
#    '慶豐七街',
#    '慶豐三街',
#    '慶豐九街',
#    '慶豐二街',
#    '慶豐五街',
#    '慶豐八街',
#    '慶豐六街',
#    '慶豐十一街',
#    '慶豐十三街',
#    '慶豐十二街',
#    '慶豐十五街',
#    '慶豐十四街',
#    '慶豐十街',
#    '慶豐四街',
#    '文化',
#    '文化一街',
#    '文化七街',
#    '文化三街',
#    '文化九街',
#    '文化二街',
#    '文化五街',
#    '文化八街',
#    '文化六街',
#    '文化十一街',
#    '文化十三街',
#    '文化十二街',
#    '文化十街',
#    '文化四街',
#    '文興街',
#    '昌隆一街',
#    '昌隆七街',
#    '昌隆三街',
#    '昌隆九街',
#    '昌隆二街',
#    '昌隆五街',
#    '昌隆八街',
#    '昌隆六街',
#    '昌隆四街',
#    '明仁一街',
#    '明仁三街',
#    '明仁二街',
#    '明太街',
#    '明義一街',
#    '明義七街',
#    '明義三街',
#    '明義二街',
#    '明義五街',
#    '明義六街',
#    '明義四街',
#    '東海一街',
#    '東海七街',
#    '東海三街',
#    '東海二街',
#    '東海五街',
#    '東海八街',
#    '東海六街',
#    '東海十一街',
#    '東海十三街',
#    '東海十五街',
#    '東海十四街',
#    '東海十街',
#    '東海四街',
#    '東里一街',
#    '東里七街',
#    '東里三街',
#    '東里九街',
#    '東里二街',
#    '東里五街',
#    '東里八街',
#    '東里十一街',
#    '東里十二街',
#    '東里十五街',
#    '東里十四街',
#    '東里十街',
#    '東里四街',
#    '榮光',
#    '正德街',
#    '民治路',
#    '永勝街',
#    '永吉一街',
#    '永吉七街',
#    '永吉三街',
#    '永吉二街',
#    '永吉五街',
#    '永吉八街',
#    '永吉四街',
#    '永吉路１段',
#    '永昌街',
#    '永昌路',
#    '永福街',
#    '永興一街',
#    '永興七街',
#    '永興三街',
#    '永興九街',
#    '永興二街',
#    '永興五街',
#    '永興八街',
#    '永興六街',
#    '永興四街',
#    '永華一街',
#    '永豐路',
#    '海岸路',
#    '海濱',
#    '知卡宣大道１段',
#    '知卡宣大道２段',
#    '知卡宣大道３段',
#    '福德街',
#    '福昌一街',
#    '福昌三街',
#    '福昌二街',
#    '福昌路',
#    '福昌路１段',
#    '福興一街',
#    '福興七街',
#    '福興三街',
#    '福興二街',
#    '福興五街',
#    '福興八街',
#    '福興六街',
#    '福興四街',
#    '福興路',
#    '稻興一街',
#    '稻興三街',
#    '稻興二街',
#    '稻香一街',
#    '稻香三街',
#    '稻香二街',
#    '稻香五街',
#    '稻香六街',
#    '稻香四街',
#    '稻香路',
#    '自信街',
#    '自強路',
#    '自強路自強巷',
#    '自樂街',
#    '自治路',
#    '自立二街',
#    '自立路',
#    '自立路１段',
#    '自立路２段',
#    '舊村一街',
#    '舊村三街',
#    '舊村二街',
#    '舊村五街',
#    '舊村六街',
#    '舊村四街',
#    '荳蘭一街',
#    '荳蘭七街',
#    '荳蘭三街',
#    '荳蘭二街',
#    '荳蘭五街',
#    '荳蘭六街',
#    '荳蘭四街',
#    '莊敬路',
#    '華中一路',
#    '華中路',
#    '華南二路',
#    '華城一街',
#    '華城七街',
#    '華城三街',
#    '華城九街',
#    '華城二街',
#    '華城五街',
#    '華城八街',
#    '華城六街',
#    '華城路１段',
#    '華城路２段',
#    '華工三路',
#    '華工五路',
#    '華工六路',
#    '華工四路',
#    '華興一街',
#    '華興七街',
#    '華興三街',
#    '華興二街',
#    '華興五街',
#    '華興六街',
#    '華興四街',
#    '香源街',
#    '香源路'],
#   '壽豐鄉': ['三區',
#    '三農場',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中山路４段',
#    '中山路５段',
#    '中山路６段',
#    '中山路７段',
#    '中正一邨',
#    '中正路',
#    '中興街',
#    '中興路',
#    '中華路１段',
#    '中華路２段',
#    '中華路３段',
#    '久富',
#    '五區',
#    '仁愛街１段',
#    '信義街',
#    '光榮一街',
#    '光榮三街',
#    '光榮二街',
#    '光榮五街',
#    '光榮四街',
#    '公園路',
#    '北坑',
#    '南坑',
#    '吉利街',
#    '吳全',
#    '四健會',
#    '四區',
#    '四維路',
#    '塩寮',
#    '壽山路',
#    '壽文路',
#    '壽興街',
#    '壽豐路１段',
#    '壽豐路２段',
#    '壽農',
#    '大同路',
#    '大坑',
#    '大學路１段',
#    '大學路２段',
#    '大樹腳',
#    '大橋',
#    '大湖角',
#    '富吉街',
#    '居南邨',
#    '山嶺',
#    '山邊路１段',
#    '山邊路２段',
#    '山邊路３段',
#    '市場',
#    '平和一街',
#    '平和二街',
#    '平和路',
#    '廣玄',
#    '志光街',
#    '志學新邨',
#    '志新街',
#    '志昌街',
#    '忠孝',
#    '忠孝街１段',
#    '擷雲莊',
#    '文化街',
#    '新站',
#    '月眉１段',
#    '月眉２段',
#    '月眉３段',
#    '月眉５段',
#    '月眉６段',
#    '東坪街',
#    '東安街',
#    '東富街',
#    '東新街',
#    '東華大學',
#    '東豐街',
#    '林園路',
#    '榮光街',
#    '樹湖',
#    '橄樹腳',
#    '橋下',
#    '民族街',
#    '民權街',
#    '民生街',
#    '水尾甲',
#    '水新路',
#    '水璉一街',
#    '水璉二街',
#    '水璉路',
#    '池南路１段',
#    '池南路２段',
#    '池南路３段',
#    '池南路４段',
#    '池南路５段',
#    '溪南',
#    '溪口一街',
#    '溪口三街',
#    '溪口二街',
#    '溪口四街',
#    '溪口路',
#    '溪頭',
#    '烏杙',
#    '牛山',
#    '牧場',
#    '理想路',
#    '環潭北路',
#    '環潭南路',
#    '白鮑',
#    '知亞甘',
#    '福德',
#    '站前街',
#    '米棧１段',
#    '米棧２段',
#    '精鍾路',
#    '素心邨',
#    '芳寮',
#    '荖山',
#    '荖溪',
#    '豐坪村中山路',
#    '豐坪路１段',
#    '豐坪路２段',
#    '豐坪路３段',
#    '豐富街',
#    '豐山村中山路',
#    '豐山村仁愛街',
#    '豐山村和平街',
#    '豐山村忠孝街',
#    '豐山街',
#    '豐德街',
#    '豐文路',
#    '豐正路',
#    '豐正路１段',
#    '豐正路２段',
#    '豐興街２段',
#    '豐裕街',
#    '豐裡一街',
#    '豐裡二街',
#    '豐裡村中山路',
#    '豐裡村仁愛街',
#    '豐裡村和平街',
#    '豐裡村忠孝街',
#    '路內',
#    '轉播台',
#    '農墾一街',
#    '農墾三街',
#    '農墾二街',
#    '銅蘭',
#    '魚塘',
#    '魚池'],
#   '鳳林鎮': ['中信路',
#    '中和路',
#    '中安路',
#    '中山路',
#    '中正路１段',
#    '中正路２段',
#    '中泰路',
#    '中環路',
#    '中科路',
#    '中美路',
#    '中興路',
#    '中華路',
#    '中長路',
#    '仁德路',
#    '仁愛街',
#    '仁盛路',
#    '信義路',
#    '光復路',
#    '光華路',
#    '八德路',
#    '公園路',
#    '公正東街',
#    '公正街',
#    '博愛街',
#    '和平街',
#    '四維路',
#    '大仁路',
#    '大功街',
#    '大同街',
#    '大忠路',
#    '大慶路',
#    '大成街',
#    '大新路',
#    '大智路',
#    '大榮一路',
#    '大榮三路',
#    '大榮二路',
#    '大榮五路',
#    '大榮四路',
#    '大聖路',
#    '大華路',
#    '大賢路',
#    '大進東街',
#    '大進街',
#    '大雅街',
#    '山吉路',
#    '山文路',
#    '山明路',
#    '山興路',
#    '山英路',
#    '平信路',
#    '平利路',
#    '平勤路',
#    '平吉路',
#    '平和路',
#    '平善路',
#    '平園路',
#    '平安路',
#    '平康路',
#    '平樂路',
#    '平漢路',
#    '平生路',
#    '平祥路',
#    '平等路',
#    '平順路',
#    '建國街',
#    '復興路',
#    '忠一路',
#    '忠二路',
#    '忠孝路',
#    '忠義路',
#    '成信街',
#    '成功街',
#    '新生東街',
#    '新生街',
#    '林安路',
#    '林森路',
#    '林榮路',
#    '榮開路',
#    '正信路',
#    '正義路',
#    '民享路',
#    '民利路',
#    '民和路',
#    '民國街',
#    '民安路',
#    '民族街',
#    '民樂路',
#    '民權路',
#    '民治路',
#    '民生街',
#    '水源路',
#    '水車路',
#    '永信路',
#    '永吉街',
#    '永安街',
#    '永康路',
#    '永福街',
#    '永豐路',
#    '箭瑛路',
#    '自強路',
#    '華興街',
#    '萬森路',
#    '農園路',
#    '農會地',
#    '長一路',
#    '長二路',
#    '長安路',
#    '長德街',
#    '長橋路',
#    '長沙路',
#    '長泰路',
#    '鳳凰路',
#    '鳳智',
#    '鳳義',
#    '鳳鳴一路',
#    '鳳鳴二路'],
#   '光復鄉': ['中學街',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中正路１段',
#    '中正路２段',
#    '中興路',
#    '中華路',
#    '仁愛路',
#    '佛祖街',
#    '光復路',
#    '光華街',
#    '光豐路',
#    '八德街',
#    '公園街',
#    '和平街',
#    '四維街',
#    '大全街',
#    '大華街',
#    '大豐',
#    '大進街',
#    '大馬',
#    '學士街',
#    '富強街',
#    '富愛街',
#    '富田一街',
#    '富田三街',
#    '富田二街',
#    '尚德街',
#    '延平街',
#    '建國路',
#    '建國路１段',
#    '建國路２段',
#    '復興街',
#    '忠孝路',
#    '慶華街',
#    '成功街',
#    '敦厚路',
#    '明德路',
#    '東富路',
#    '林森路',
#    '武昌街',
#    '民族街',
#    '民有街',
#    '民權街',
#    '民治街',
#    '民生街',
#    '糖廠街',
#    '自強路',
#    '華新街',
#    '西富路',
#    '農場路'],
#   '豐濱鄉': ['三富橋',
#    '三民路',
#    '信義橋',
#    '光豐路',
#    '和平橋',
#    '大港口',
#    '富光',
#    '小港',
#    '小湖',
#    '後湖',
#    '復興',
#    '忠孝橋',
#    '新峰',
#    '新社',
#    '新興',
#    '東興',
#    '民族街',
#    '民權街',
#    '民生街',
#    '永豐',
#    '港口',
#    '石梯坪',
#    '石梯港',
#    '石梯灣',
#    '石門',
#    '磯崎',
#    '立德',
#    '芭奇',
#    '英雄崗',
#    '豐富',
#    '豐里',
#    '開發橋',
#    '靜浦',
#    '高山',
#    '龜庵'],
#   '瑞穗鄉': ['一心路',
#    '七賢路',
#    '三多路',
#    '中山路１段',
#    '中山路２段',
#    '中山路３段',
#    '中強路',
#    '中正北路１段',
#    '中正北路２段',
#    '中正北路３段',
#    '中正南路１段',
#    '中正南路２段',
#    '中正南路３段',
#    '中正路',
#    '中正路１段',
#    '中興路',
#    '中華路',
#    '九如路',
#    '二聖路',
#    '五福路',
#    '仁愛一街',
#    '仁愛三街',
#    '仁愛五街',
#    '仁愛六街',
#    '仁愛路',
#    '保安路',
#    '信義路',
#    '八德路',
#    '六合路',
#    '力天路',
#    '力行路',
#    '北一路',
#    '北三路',
#    '北二路',
#    '北五路',
#    '北六路',
#    '十全街',
#    '十美街',
#    '南一路',
#    '南三路',
#    '南二路',
#    '南五路',
#    '南元路',
#    '南六路',
#    '博愛路',
#    '和平路',
#    '四維路',
#    '國光北路',
#    '國光南路',
#    '奇美',
#    '學士路',
#    '學府路',
#    '安夜溪路',
#    '富國街',
#    '富民',
#    '富源路',
#    '富興',
#    '富貴路',
#    '屋拉力一街',
#    '屋拉力三街',
#    '屋拉力二街',
#    '屋拉力四街',
#    '市場一路',
#    '市場街',
#    '平埔路',
#    '平頂路',
#    '廣東路',
#    '廣東路一街',
#    '廣東路二街',
#    '廣東路六街',
#    '廣東路四街',
#    '廣興路',
#    '復興街',
#    '忠孝路',
#    '慈天路',
#    '慈安路',
#    '成功北路',
#    '成功南路',
#    '掃叭頂一路',
#    '掃叭頂二路',
#    '掃叭頂四路',
#    '文化路',
#    '文昌街',
#    '新生一路',
#    '新生路',
#    '新興路',
#    '東興路',
#    '梧繞一街',
#    '梧繞三街',
#    '梧繞二街',
#    '梧繞四街',
#    '梧繞路',
#    '民一街',
#    '民七街',
#    '民三街',
#    '民二街',
#    '民五街',
#    '民享一街',
#    '民享路',
#    '民六街',
#    '民四街',
#    '民有一街',
#    '民有路',
#    '民權東路',
#    '民權西路',
#    '民生街',
#    '水源路',
#    '源興路',
#    '溫泉路１段',
#    '溫泉路２段',
#    '溫泉路３段',
#    '瑞北',
#    '瑞北車站路',
#    '瑞安路',
#    '瑞平路',
#    '瑞強路',
#    '瑞益路',
#    '瑞祥',
#    '瑞蓮路',
#    '瑞達路１段',
#    '瑞達路２段',
#    '祥北路１段',
#    '祥北路２段',
#    '福德路',
#    '竹圍路',
#    '自強新村',
#    '自立新村',
#    '至善路',
#    '興鶴一街',
#    '興鶴二街',
#    '興鶴路１段',
#    '興鶴路２段',
#    '興鶴路３段',
#    '舞鶴',
#    '萬生路',
#    '迦納納二路',
#    '迦納納六路',
#    '迦納納四路',
#    '連興路',
#    '青山一街',
#    '青山二街',
#    '馬立雲路',
#    '鶴岡',
#    '鶴東路'],
#   '萬榮鄉': ['忠孝路', '明利', '紅葉', '萬榮', '西林', '見晴', '馬遠'],
#   '玉里鎮': ['三民',
#    '三軒',
#    '中山路１段',
#    '中山路２段',
#    '中正路',
#    '中興街',
#    '中華路',
#    '主權街',
#    '五權街',
#    '仁愛路１段',
#    '仁愛路２段',
#    '信義街',
#    '光復路',
#    '光明街',
#    '公正街',
#    '北平街',
#    '協和街',
#    '協興街',
#    '南通',
#    '博愛路',
#    '台鳳街',
#    '和平路',
#    '四維一街',
#    '四維二街',
#    '坪頂',
#    '城中一街',
#    '城中三街',
#    '城中二街',
#    '城中五街',
#    '城中四街',
#    '城南一街',
#    '城南七街',
#    '城南三街',
#    '城南九街',
#    '城南二街',
#    '城南五街',
#    '城南八街',
#    '城南六街',
#    '城南十街',
#    '城南四街',
#    '城東一街',
#    '城東七街',
#    '城東三街',
#    '城東二街',
#    '城東五街',
#    '城東八街',
#    '城東六街',
#    '城東四街',
#    '城西一街',
#    '城西三街',
#    '城西二街',
#    '城西五街',
#    '城西六街',
#    '城西四街',
#    '城西街',
#    '大同路',
#    '大禹',
#    '安通',
#    '客城',
#    '宮前',
#    '富國街',
#    '康樂街',
#    '廉明街',
#    '建國一街',
#    '建國三街',
#    '建國二街',
#    '建國五街',
#    '建國四街',
#    '復興街',
#    '德武',
#    '忠仁路',
#    '忠勇路',
#    '忠孝三街',
#    '忠孝二街',
#    '忠孝五街',
#    '忠孝路',
#    '忠智路',
#    '忠義',
#    '成功街',
#    '文昌街',
#    '新昌一街',
#    '新民',
#    '新生街',
#    '新興街',
#    '更生路',
#    '東園街',
#    '東平街',
#    '松浦',
#    '棣芬',
#    '樂合',
#    '樂園街',
#    '樂圓',
#    '正義街',
#    '民國路１段',
#    '民國路２段',
#    '民安一街',
#    '民安三街',
#    '民安二街',
#    '民安四街',
#    '民族街',
#    '民族路',
#    '民權街',
#    '民生街',
#    '水源',
#    '泰林',
#    '溫泉',
#    '石崗',
#    '神農',
#    '福安街',
#    '福崗',
#    '竹林',
#    '能雅',
#    '自強三街',
#    '自強五街',
#    '自強六街',
#    '自強四街',
#    '自強街',
#    '自由街',
#    '興國路１段',
#    '興國路２段',
#    '莊敬路',
#    '萬麗',
#    '蕉山',
#    '西園街',
#    '西邊街',
#    '觀音',
#    '贊平',
#    '酸柑',
#    '長良',
#    '集賢街',
#    '高寮'],
#   '卓溪鄉': ['中平',
#    '中正',
#    '中興',
#    '卓樂',
#    '卓溪',
#    '南安',
#    '古楓',
#    '太平',
#    '山里',
#    '崙天',
#    '崙山',
#    '清水',
#    '白端',
#    '石平',
#    '秀蘭',
#    '立山'],
#   '富里鄉': ['三台',
#    '中山路',
#    '中興路',
#    '光明路',
#    '公埔路',
#    '公埔路２段',
#    '公界街',
#    '六十石山',
#    '南興路',
#    '后庄路',
#    '吳江',
#    '和平街',
#    '四維',
#    '大莊路',
#    '學富路',
#    '安通',
#    '安靜街',
#    '富北',
#    '富南',
#    '富田',
#    '富豐路',
#    '廣興路',
#    '復興路',
#    '慶光路',
#    '文化路',
#    '新富',
#    '新興',
#    '新莊',
#    '明里',
#    '朝寧',
#    '東寧',
#    '東昇路',
#    '東湖',
#    '東竹',
#    '東興',
#    '東里村復興',
#    '民權路',
#    '永安街',
#    '永豐',
#    '永豐村復興',
#    '清坑',
#    '湧泉路',
#    '源和',
#    '石牌',
#    '福安路',
#    '福崗',
#    '羅山',
#    '草坪',
#    '萬寧',
#    '豐南',
#    '豐南村復興',
#    '車站街',
#    '車站街１段',
#    '道化路',
#    '鎮寧',
#    '雲閩']}}

# %%
with open('city_area_road.pkl', 'rb') as f:
    data1 = {"縣市": ''}
    data2 = pickle.load(f)
    data2['南海島'] = {'南海島':'南海島'}
    data = {}
    data.update(data1)
    data.update(data2)

# %%
data['南海島'].keys()
# Out:
# dict_keys(['南海島'])
